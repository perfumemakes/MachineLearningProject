# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/water-potability/water_potability.csv

# %% [markdown]
# ### Feature Description
#
# ph: pH of 1. water (0 to 14).
#
# Hardness: Capacity of water to precipitate soap in mg/L.
#
# Solids: Total dissolved solids in ppm.
#
# Chloramines: Amount of Chloramines in ppm.
#
# Sulfate: Amount of Sulfates dissolved in mg/L.
#
# Conductivity: Electrical conductivity of water in μS/cm.
#
# Organic_carbon: Amount of organic carbon in ppm.
#
# Trihalomethanes: Amount of Trihalomethanes in μg/L.
#
# Turbidity: Measure of light emiting property of water in NTU.
#
# Potability: Indicates if water is safe for human consumption. Potable - 1 and Not potable - 0

# %%
data=pd.read_csv('/kaggle/input/water-potability/water_potability.csv')
data=pd.DataFrame(data)

# %%
data.head(10)
# Out:
#           ph    Hardness        Solids  Chloramines     Sulfate  Conductivity  \
# 0        NaN  204.890455  20791.318981     7.300212  368.516441    564.308654
# 1   3.716080  129.422921  18630.057858     6.635246         NaN    592.885359
# 2   8.099124  224.236259  19909.541732     9.275884         NaN    418.606213
# 3   8.316766  214.373394  22018.417441     8.059332  356.886136    363.266516
# 4   9.092223  181.101509  17978.986339     6.546600  310.135738    398.410813
# 5   5.584087  188.313324  28748.687739     7.544869  326.678363    280.467916
# 6  10.223862  248.071735  28749.716544     7.513408  393.663396    283.651634
# 7   8.635849  203.361523  13672.091764     4.563009  303.309771    474.607645
# 8        NaN  118.988579  14285.583854     7.804174  268.646941    389.375566
# 9  11.180284  227.231469  25484.508491     9.077200  404.041635    563.885481
#
#    Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       10.379783        86.990970   2.963135           0
# 1       15.180013        56.329076   4.500656           0
# 2       16.868637        66.420093   3.055934           0
# 3       18.436524       100.341674   4.628771           0
# 4       11.558279        31.997993   4.075075           0
# 5        8.399735        54.917862   2.559708           0
# 6       13.789695        84.603556   2.672989           0
# 7       12.363817        62.798309   4.401425           0
# 8       12.706049        53.928846   3.595017           0
# 9       17.927806        71.976601   4.370562           0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3276 entries, 0 to 3275
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ph               2785 non-null   float64
#  1   Hardness         3276 non-null   float64
#  2   Solids           3276 non-null   float64
#  3   Chloramines      3276 non-null   float64
#  4   Sulfate          2495 non-null   float64
#  5   Conductivity     3276 non-null   float64
#  6   Organic_carbon   3276 non-null   float64
#  7   Trihalomethanes  3114 non-null   float64
#  8   Turbidity        3276 non-null   float64
#  9   Potability       3276 non-null   int64
# dtypes: float64(9), int64(1)
# memory usage: 256.1 KB

# %%
sns.heatmap(data.isnull(), cbar=False)
plt.xticks(rotation=45)
plt.show()

# %%
data.isnull().sum()
# Out:
# ph                 491
# Hardness             0
# Solids               0
# Chloramines          0
# Sulfate            781
# Conductivity         0
# Organic_carbon       0
# Trihalomethanes    162
# Turbidity            0
# Potability           0
# dtype: int64

# %%
data['Potability'].value_counts()
# Out:
# 0    1998
# 1    1278
# Name: Potability, dtype: int64

# %% [markdown]
# # 결측치 처리(ph, Sulfate, Trihalomethanes)
#
# - 1. dropna(null값을 포함한 데이터는 drop한다) => 데이터가 1526개로 약 절반가량으로 줄어든다.=> RandomForest 정확도가 상대적으로 낮다
# - 2. null값이 있는 column을 drop한다.=> feature가 9개에서 6개로 줄어든다.=> RamdomForest 정확도가 상대적으로 낮다
# - 3. Feature의 평균값 또는 중앙값으로 대체한다.=> RandomForest 정확도가 상대적으로 높다.

# %%
# 결측치 평균값으로 대체-1

data.loc[(data['Potability'] == 0) & (data['ph'].isna()), 'ph'] = data[data['Potability'] == 0]['ph'].mean(skipna=True)
data.loc[(data['Potability'] == 1) & (data['ph'].isna()), 'ph'] = data[data['Potability'] == 1]['ph'].mean(skipna=True)


data.loc[(data['Potability'] == 0) & (data['Sulfate'].isna()), 'Sulfate'] = data[data['Potability'] == 0]['Sulfate'].mean(skipna=True)
data.loc[(data['Potability'] == 1) & (data['Sulfate'].isna()), 'Sulfate'] = data[data['Potability'] == 1]['Sulfate'].mean(skipna=True)


data.loc[(data['Potability'] == 0) & (data['Trihalomethanes'].isna()), 'Trihalomethanes'] = data[data['Potability'] == 0]['Trihalomethanes'].mean(skipna=True)
data.loc[(data['Potability'] == 1) & (data['Trihalomethanes'].isna()), 'Trihalomethanes'] = data[data['Potability'] == 1]['Trihalomethanes'].mean(skipna=True)

# %%
# 결측치 중앙값으로 대체-2

#data.loc[(data['Potability'] == 0) & (data['ph'].isna()), 'ph'] = data[data['Potability'] == 0]['ph'].median(skipna=True)
#data.loc[(data['Potability'] == 1) & (data['ph'].isna()), 'ph'] = data[data['Potability'] == 1]['ph'].median(skipna=True)


#data.loc[(data['Potability'] == 0) & (data['Sulfate'].isna()), 'Sulfate'] = data[data['Potability'] == 0]['Sulfate'].median(skipna=True)
#data.loc[(data['Potability'] == 1) & (data['Sulfate'].isna()), 'Sulfate'] = data[data['Potability'] == 1]['Sulfate'].median(skipna=True)


#data.loc[(data['Potability'] == 0) & (data['Trihalomethanes'].isna()), 'Trihalomethanes'] = data[data['Potability'] == 0]['Trihalomethanes'].median(skipna=True)
#data.loc[(data['Potability'] == 1) & (data['Trihalomethanes'].isna()), 'Trihalomethanes'] = data[data['Potability'] == 1]['Trihalomethanes'].median(skipna=True)

# %%
from sklearn.model_selection import train_test_split
X = data.iloc[:, :-1]
y = data.iloc[:, -1]
X_train,X_test,y_train,y_test=train_test_split(X, y, test_size=0.3, random_state=0)

# %%
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((2293, 9), (2293,), (983, 9), (983,))

# %% [markdown]
# ### Preprocessing

# %%
from sklearn.preprocessing import StandardScaler
sclaer=StandardScaler()
X_train=sclaer.fit_transform(X_train)
X_test=sclaer.transform(X_test)
X_train=pd.DataFrame(X_train)
X_test=pd.DataFrame(X_test)

# %%
X_train=X_train.rename(columns={0:'ph',1:'Hardness', 2:'Solids',3:'Chloramines',4:'Sulfate', 5:'Conductivity',6:'Organic_carbon',7:'Trihalomethanes', 8:'Turbidity'})
X_test=X_test.rename(columns={0:'ph',1:'Hardness', 2:'Solids',3:'Chloramines',4:'Sulfate', 5:'Conductivity',6:'Organic_carbon',7:'Trihalomethanes', 8:'Turbidity'})

# %% [markdown]
# ### SMOTE 적용해보기

# %%
#from sklearn.datasets import make_classification
#from sklearn.decomposition import PCA
#from imblearn.over_sampling import SMOTE

# %%
#SMOTE?

# %%
#smote = SMOTE(sampling_strategy='auto',
#   random_state=None,
#    k_neighbors=5,
#    n_jobs=None,)
#X_resampled, y_resampled = smote.fit_resample(X_train,y_train)

# %%
#X_resampled.shape, y_resampled.shape

# %%
#y_resampled.value_counts()

# %%
#X_train=pd.concat([X_train, X_resampled])
#X_train.shape

# %%
#y_train=pd.concat([y_train,y_resampled])
#y_train.shape

# %%
#y_train=pd.DataFrame(y_train)
#y_test=pd.DataFrame(y_test)

# %% [markdown]
# ### Machine Learning
# - Modeling

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((2293, 9), (983, 9), (2293,), (983,))

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score


models_acc = []
models_f1 = []
models = [DecisionTreeClassifier(), LogisticRegression(), KNeighborsClassifier(), RandomForestClassifier(), GaussianNB(), SVC()]
for model in models:
    model.fit(X_train, y_train)    
    pred = model.predict(X_test)
    models_acc.append(accuracy_score(y_test, pred))
    models_f1.append(f1_score(y_test, pred))

# %%
Model_list = pd.DataFrame({
    'Model Accuracy': models_acc, 
    "Model Name": ['DecisionTreeClassifier','LogisticRegression', 'KNeighborsClassifier', 'RandomForestClassifier', 'GaussianNB', 'SVC'],
    "Model f1 score": models_f1
})
Model_list
# Out:
#    Model Accuracy              Model Name  Model f1 score
# 0        0.745677  DecisionTreeClassifier        0.655647
# 1        0.624619      LogisticRegression        0.021220
# 2        0.635809    KNeighborsClassifier        0.459215
# 3        0.811801  RandomForestClassifier        0.723468
# 4        0.611394              GaussianNB        0.312950
# 5        0.682604                     SVC        0.400000

# %% [markdown]
# ### Gridsearch

# %%
from sklearn.model_selection import GridSearchCV

rfc = RandomForestClassifier(random_state=0, class_weight='balanced', criterion='entropy')
#파라미터 후보 - 딕셔너리(key: 하이퍼 파라미터 이름, value: 후보리스트)
param_grid = {
    'n_estimators':range(100,1001,100),
    'max_depth':[6, 8, 10, 12],
    'min_samples_leaf':[2 ,4, 6, 8],
    'min_samples_split':[2 ,4, 6,8]
}

grid_search = GridSearchCV(rfc, #모델
                           param_grid=param_grid, #하이퍼 파라미터 후보
                           scoring='accuracy',# 평가 지표
                           cv=4, # cross validation의 fold 개수
                           n_jobs=-1) # 사용할 cpu의 개수: -1은 모든 cpu 전부 사용(병렬 학습)

# %%
grid_search.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=4,
#              estimator=RandomForestClassifier(class_weight='balanced',
#                                               criterion='entropy',
#                                               random_state=0),
#              n_jobs=-1,
#              param_grid={'max_depth': [6, 8, 10, 12],
#                          'min_samples_leaf': [2, 4, 6, 8],
#                          'min_samples_split': [2, 4, 6, 8],
#                          'n_estimators': range(100, 1001, 100)},
#              scoring='accuracy')

# %%
df = pd.DataFrame(grid_search.cv_results_).sort_values('rank_test_score')#.filter(like='rank')
df
# Out:
#      mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 500       0.883677      0.014135         0.034423        0.001285
# 505       5.342476      0.134721         0.182529        0.002974
# 506       6.613830      0.199612         0.214367        0.000687
# 504       4.534849      0.117037         0.157735        0.005258
# 502       3.082324      0.504625         0.093476        0.001641
# ..             ...           ...              ...             ...
# 82        2.048652      0.022102         0.094560        0.004250
# 131       1.452613      0.130179         0.058713        0.000979
# 141       1.313801      0.006201         0.060611        0.003372
# 151       1.311068      0.004128         0.059225        0.002031
# 121       1.497603      0.195737         0.069522        0.017414
#
#     param_max_depth param_min_samples_leaf param_min_samples_split  \
# 500              12                      2                       6
# 505              12                      2                       6
# 506              12                      2                       6
# 504              12                      2                       6
# 502              12                      2                       6
# ..              ...                    ...                     ...
# 82                6                      6                       2
# 131               6                      8                       4
# 141               6                      8                       6
# 151               6                      8                       8
# 121               6                      8                       2
#
#     param_n_estimators                                             params  \
# 500                100  {'max_depth': 12, 'min_samples_leaf': 2, 'min_...
# 505                600  {'max_depth': 12, 'min_samples_leaf': 2, 'min_...
# 506                700  {'max_depth': 12, 'min_samples_leaf': 2, 'min_...
# 504                500  {'max_depth': 12, 'min_samples_leaf': 2, 'min_...
# 502                300  {'max_depth': 12, 'min_samples_leaf': 2, 'min_...
# ..                 ...                                                ...
# 82                 300  {'max_depth': 6, 'min_samples_leaf': 6, 'min_s...
# 131                200  {'max_depth': 6, 'min_samples_leaf': 8, 'min_s...
# 141                200  {'max_depth': 6, 'min_samples_leaf': 8, 'min_s...
# 151                200  {'max_depth': 6, 'min_samples_leaf': 8, 'min_s...
# 121                200  {'max_depth': 6, 'min_samples_leaf': 8, 'min_s...
#
#      split0_test_score  split1_test_score  split2_test_score  \
# 500           0.766551           0.785340           0.774869
# 505           0.761324           0.785340           0.769634
# 506           0.764808           0.780105           0.769634
# 504           0.761324           0.787086           0.766143
# 502           0.763066           0.788831           0.771379
# ..                 ...                ...                ...
# 82            0.735192           0.766143           0.746946
# 131           0.736934           0.760908           0.739965
# 141           0.736934           0.760908           0.739965
# 151           0.736934           0.760908           0.739965
# 121           0.736934           0.760908           0.739965
#
#      split3_test_score  mean_test_score  std_test_score  rank_test_score
# 500           0.778360         0.776280        0.006765                1
# 505           0.787086         0.775846        0.010793                2
# 506           0.785340         0.774972        0.008149                3
# 504           0.783595         0.774537        0.011006                4
# 502           0.774869         0.774536        0.009300                5
# ..                 ...              ...             ...              ...
# 82            0.752182         0.750116        0.011112              633
# 131           0.759162         0.749242        0.010863              637
# 141           0.759162         0.749242        0.010863              637
# 151           0.759162         0.749242        0.010863              637
# 121           0.759162         0.749242        0.010863              637
#
# [640 rows x 16 columns]

# %%
grid_search.best_score_
# Out:
# 0.7762798645189145

# %%
grid_search.best_params_
# Out:
# {'max_depth': 12,
#  'min_samples_leaf': 2,
#  'min_samples_split': 6,
#  'n_estimators': 100}

# %%
best_model = grid_search.best_estimator_
accuracy_score(y_test, best_model.predict(X_test))
# Out:
# 0.7965412004069176

# %%
pred=best_model.predict(X_test)

# %%
print("Accuracy:", accuracy_score(y_test, pred)*100,'%') 
print("Recall:", recall_score(y_test, pred)*100,'%') 
print('Precision:',precision_score(y_test, pred)*100, '%') 
print('f1 score:',f1_score(y_test, pred)*100, '%')
# Out:
# Accuracy: 79.65412004069175 %
# Recall: 67.29222520107238 %
# Precision: 76.29179331306992 %
# f1 score: 71.50997150997152 %

# %%
fi=best_model.feature_importances_
fi=pd.Series(fi, index=X_train.columns)
fi
# Out:
# ph                 0.213248
# Hardness           0.074843
# Solids             0.071228
# Chloramines        0.075915
# Sulfate            0.345524
# Conductivity       0.052480
# Organic_carbon     0.057243
# Trihalomethanes    0.059938
# Turbidity          0.049582
# dtype: float64

# %%
fi.sort_values().plot(kind='barh', figsize=(8,8))
plt.show()

# %% [markdown]
# ### Evaluation
# - RandomForest

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay
plt.figure(figsize=(7,7))
ax = plt.gca()
cm = confusion_matrix(y_test, pred)
disp = ConfusionMatrixDisplay(cm, # confusion matrix
                              display_labels=['0', '1']) # [음성레이블, 양성레이블]
disp.plot(cmap='Blues', ax=ax) # 출력
plt.title('Test set')
plt.show()

# %%
from sklearn.metrics import precision_score, average_precision_score,precision_recall_curve
from sklearn.metrics import PrecisionRecallDisplay 

rfc= best_model.predict_proba(X_test)[:, 1]
precision, recall, _ = precision_recall_curve(y_test, rfc)
ap_rfc = average_precision_score(y_test, rfc)

plt.figure(figsize=(8,8))
ax = plt.gca()
disp = PrecisionRecallDisplay(precision, recall, average_precision=ap_rfc)
disp.plot(ax=ax);
plt.grid(True)
plt.xticks(np.arange(0,1.1,0.1))
plt.yticks(np.arange(0,1.1,0.1))
plt.show()

# %%
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from sklearn.metrics import RocCurveDisplay

auc_rfc = roc_auc_score(y_test, rfc)
fprs_rfc, tprs_rfc, _ = roc_curve(y_test, rfc)


plt.figure(figsize=(7,6))
ax = plt.gca()
disp = RocCurveDisplay(fpr=fprs_rfc, tpr=tprs_rfc, roc_auc=auc_rfc, estimator_name='random forest')
disp.plot(ax=ax)
plt.show()

# %% [markdown]
# ### Deep Learning
# - MLP

# %%
import tensorflow as tf
from tensorflow import keras

model = keras.Sequential()
model.add(keras.layers.InputLayer((1,9))) 
model.add(keras.layers.Flatten())  
model.add(keras.layers.Dense(256, activation='relu'))
model.add(keras.layers.Dense(128, activation='relu'))
model.add(keras.layers.Dense(64, activation='relu'))
model.add(keras.layers.Dense(32, activation='relu'))
model.add(keras.layers.Dense(1, activation='softmax'))

# %%
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])
hist = model.fit(X_train, y_train, 
                  epochs=10,
                  batch_size=9,
                  validation_split=0.3 
                 )

test_loss, test_acc = model.evaluate(X_test, y_test)
# Out:
# Epoch 1/10
# 179/179 [==============================] - 1s 5ms/step - loss: 0.0000e+00 - accuracy: 0.3844 - val_loss: 0.0000e+00 - val_accuracy: 0.4186
# Epoch 2/10
# 179/179 [==============================] - 1s 6ms/step - loss: 0.0000e+00 - accuracy: 0.3844 - val_loss: 0.0000e+00 - val_accuracy: 0.4186
# Epoch 3/10
# 179/179 [==============================] - 1s 4ms/step - loss: 0.0000e+00 - accuracy: 0.3844 - val_loss: 0.0000e+00 - val_accuracy: 0.4186
# Epoch 4/10
# 179/179 [==============================] - 1s 4ms/step - loss: 0.0000e+00 - accuracy: 0.3844 - val_loss: 0.0000e+00 - val_accuracy: 0.4186
# Epoch 5/10
# 179/179 [==============================] - 1s 4ms/step - loss: 0.0000e+00 - accuracy: 0.3844 - val_loss: 0.0000e+00 - val_accuracy: 0.4186
# Epoch 6/10
# 179/179 [==============================] - 1s 5ms/step - loss: 0.0000e+00 - accuracy: 0.3844 - val_loss: 0.0000e+00 - val_accuracy: 0.4186
# Epoch 7/10
# 179/179 [==============================] - 1s 5ms/step - loss: 0.0000e+00 - accuracy: 0.3844 - val_loss: 0.0000e+00 - val_accuracy: 0.4186
# Epoch 8/10
# 179/179 [==============================] - 1s 5ms/step - loss: 0.0000e+00 - accuracy: 0.3844 - val_loss: 0.0000e+00 - val_accuracy: 0.4186
# Epoch 9/10
# 179/179 [==============================] - 1s 4ms/step - loss: 0.0000e+00 - accuracy: 0.3844 - val_loss: 0.0000e+00 - val_accuracy: 0.4186
# Epoch 10/10
# 179/179 [==============================] - 1s 4ms/step - loss: 0.0000e+00 - accuracy: 0.3844 - val_loss: 0.0000e+00 - val_accuracy: 0.4186
# 31/31 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.3795

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_1 (Flatten)          (None, 9)                 0
# _________________________________________________________________
# dense_5 (Dense)              (None, 256)               2560
# _________________________________________________________________
# dense_6 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dense_7 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_8 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_9 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 45,825
# Trainable params: 45,825
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.utils import plot_model
plot_model(model, to_file='model_shapes.png', show_shapes=True)

# %%
test_loss, test_acc = model.evaluate(X_test, y_test)
# Out:
# 31/31 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.3795

# %%
print(test_loss, test_acc)
# Out:
# 0.0 0.37945064902305603

# %% [markdown]
# ### Deep Learning
# - DNN

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

np.random.seed(0)
tf.random.set_seed(0)

# %%
X_train,X_val,y_train,y_val=train_test_split(X_train, y_train, test_size=0.3, random_state=0)

# %%
X_train.shape, X_val.shape, X_test.shape
# Out:
# ((1605, 9), (688, 9), (983, 9))

# %%
y_train.shape, y_val.shape, y_test.shape
# Out:
# ((1605,), (688,), (983,))

# %%
LEARNING_RATE = 0.001
N_EPOCHS = 300
N_BATCHS = 100

N_TRAIN = X_train.shape[0]
N_VAL = X_val.shape[0]
N_TEST = X_test.shape[0]

# %%
train_dataset = tf.data.Dataset.from_tensor_slices((X_train, y_train))\
                               .shuffle(N_TRAIN)\
                               .batch(N_BATCHS, drop_remainder=True)

val_dataset = tf.data.Dataset.from_tensor_slices((X_val, y_val)).batch(N_BATCHS)
test_dataset = tf.data.Dataset.from_tensor_slices((X_test, y_test)).batch(N_BATCHS)

# %%
def create_DNN_model():
    model = keras.Sequential()
    
    # 1. Flatten + Input Layer
    model.add(layers.Flatten(input_shape=(1,9))) 
    
    # 2. Hidden Layer
    model.add(layers.Dropout(0.3))
    model.add(layers.BatchNormalization())
    model.add(layers.Dense(units=256, activation='relu'))
    
    model.add(layers.Dropout(0.3))
    model.add(layers.BatchNormalization())
    model.add(layers.Dense(units=256, activation='relu'))
    
    model.add(layers.Dropout(0.3))
    model.add(layers.BatchNormalization())
    model.add(layers.Dense(units=128, activation='relu'))
    
    model.add(layers.Dropout(0.3))
    model.add(layers.BatchNormalization())
    model.add(layers.Dense(units=128, activation='relu'))
    
    model.add(layers.Dropout(0.3))
    model.add(layers.BatchNormalization())
    model.add(layers.Dense(units=64, activation='relu'))
    
    model.add(layers.Dropout(0.3))
    model.add(layers.BatchNormalization())
    model.add(layers.Dense(units=64, activation='relu'))
    
    # 3. Output Layer: 다중분류-unit수: class수, 각 unit이 클래스별 확률 => activation 함수: softmax
    model.add(layers.Dense(units=1, activation='sigmoid'))
    
    return model

# %%
model = create_DNN_model()

model.compile(optimizer=keras.optimizers.Adam(learning_rate=LEARNING_RATE), 
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_2 (Flatten)          (None, 9)                 0
# _________________________________________________________________
# dropout (Dropout)            (None, 9)                 0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 9)                 36
# _________________________________________________________________
# dense_10 (Dense)             (None, 256)               2560
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 256)               1024
# _________________________________________________________________
# dense_11 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 256)               1024
# _________________________________________________________________
# dense_12 (Dense)             (None, 128)               32896
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 128)               0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 128)               512
# _________________________________________________________________
# dense_13 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 128)               0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 128)               512
# _________________________________________________________________
# dense_14 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 64)                0
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 64)                256
# _________________________________________________________________
# dense_15 (Dense)             (None, 64)                4160
# _________________________________________________________________
# dense_16 (Dense)             (None, 1)                 65
# =================================================================
# Total params: 133,605
# Trainable params: 131,923
# Non-trainable params: 1,682
# _________________________________________________________________

# %%
hist = model.fit(train_dataset,
                 epochs=N_EPOCHS,
                 validation_data=val_dataset)
# Out:
# Epoch 1/300
# 16/16 [==============================] - 2s 23ms/step - loss: 0.7785 - accuracy: 0.4869 - val_loss: 0.6804 - val_accuracy: 0.5858
# Epoch 2/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.7129 - accuracy: 0.5544 - val_loss: 0.6780 - val_accuracy: 0.5858
# Epoch 3/300
# 16/16 [==============================] - 0s 11ms/step - loss: 0.6965 - accuracy: 0.5825 - val_loss: 0.6819 - val_accuracy: 0.5858
# Epoch 4/300
# 16/16 [==============================] - 0s 12ms/step - loss: 0.6900 - accuracy: 0.5700 - val_loss: 0.6828 - val_accuracy: 0.5858
# Epoch 5/300
# 16/16 [==============================] - 0s 11ms/step - loss: 0.6834 - accuracy: 0.5931 - val_loss: 0.6826 - val_accuracy: 0.5858
# Epoch 6/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6833 - accuracy: 0.5956 - val_loss: 0.6839 - val_accuracy: 0.5858
# Epoch 7/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6694 - accuracy: 0.6056 - val_loss: 0.6857 - val_accuracy: 0.5858
# Epoch 8/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6901 - accuracy: 0.5938 - val_loss: 0.6850 - val_accuracy: 0.5858
# Epoch 9/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6632 - accuracy: 0.6106 - val_loss: 0.6910 - val_accuracy: 0.5858
# Epoch 10/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6770 - accuracy: 0.5975 - val_loss: 0.6874 - val_accuracy: 0.5858
# Epoch 11/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6880 - accuracy: 0.5906 - val_loss: 0.6902 - val_accuracy: 0.5872
# Epoch 12/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6773 - accuracy: 0.6081 - val_loss: 0.6872 - val_accuracy: 0.5872
# Epoch 13/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6492 - accuracy: 0.6319 - val_loss: 0.6917 - val_accuracy: 0.5872
# Epoch 14/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6652 - accuracy: 0.6175 - val_loss: 0.6982 - val_accuracy: 0.5887
# Epoch 15/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6649 - accuracy: 0.6062 - val_loss: 0.7003 - val_accuracy: 0.5916
# Epoch 16/300
# 16/16 [==============================] - 0s 8ms/step - loss: 0.6665 - accuracy: 0.6050 - val_loss: 0.6878 - val_accuracy: 0.5945
# Epoch 17/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6551 - accuracy: 0.6263 - val_loss: 0.6835 - val_accuracy: 0.5959
# Epoch 18/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6510 - accuracy: 0.6344 - val_loss: 0.6825 - val_accuracy: 0.5974
# Epoch 19/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6613 - accuracy: 0.6144 - val_loss: 0.6850 - val_accuracy: 0.5988
# Epoch 20/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6524 - accuracy: 0.6338 - val_loss: 0.6832 - val_accuracy: 0.6032
# Epoch 21/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6644 - accuracy: 0.6250 - val_loss: 0.6782 - val_accuracy: 0.6003
# Epoch 22/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6610 - accuracy: 0.6200 - val_loss: 0.6720 - val_accuracy: 0.6017
# Epoch 23/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6610 - accuracy: 0.6225 - val_loss: 0.6716 - val_accuracy: 0.6047
# Epoch 24/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6472 - accuracy: 0.6313 - val_loss: 0.6662 - val_accuracy: 0.6148
# Epoch 25/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6405 - accuracy: 0.6481 - val_loss: 0.6641 - val_accuracy: 0.6250
# Epoch 26/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6637 - accuracy: 0.6212 - val_loss: 0.6614 - val_accuracy: 0.6279
# Epoch 27/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6630 - accuracy: 0.6206 - val_loss: 0.6583 - val_accuracy: 0.6221
# Epoch 28/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6498 - accuracy: 0.6400 - val_loss: 0.6553 - val_accuracy: 0.6235
# Epoch 29/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6479 - accuracy: 0.6363 - val_loss: 0.6513 - val_accuracy: 0.6323
# Epoch 30/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6540 - accuracy: 0.6331 - val_loss: 0.6495 - val_accuracy: 0.6410
# Epoch 31/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6464 - accuracy: 0.6344 - val_loss: 0.6501 - val_accuracy: 0.6323
# Epoch 32/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6532 - accuracy: 0.6281 - val_loss: 0.6470 - val_accuracy: 0.6366
# Epoch 33/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6471 - accuracy: 0.6406 - val_loss: 0.6441 - val_accuracy: 0.6337
# Epoch 34/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6526 - accuracy: 0.6319 - val_loss: 0.6496 - val_accuracy: 0.6294
# Epoch 35/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6445 - accuracy: 0.6331 - val_loss: 0.6480 - val_accuracy: 0.6337
# Epoch 36/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6452 - accuracy: 0.6375 - val_loss: 0.6488 - val_accuracy: 0.6294
# Epoch 37/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6413 - accuracy: 0.6406 - val_loss: 0.6473 - val_accuracy: 0.6279
# Epoch 38/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6449 - accuracy: 0.6419 - val_loss: 0.6511 - val_accuracy: 0.6323
# Epoch 39/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6478 - accuracy: 0.6413 - val_loss: 0.6445 - val_accuracy: 0.6410
# Epoch 40/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6329 - accuracy: 0.6519 - val_loss: 0.6423 - val_accuracy: 0.6439
# Epoch 41/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6446 - accuracy: 0.6500 - val_loss: 0.6403 - val_accuracy: 0.6410
# Epoch 42/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6401 - accuracy: 0.6562 - val_loss: 0.6429 - val_accuracy: 0.6395
# Epoch 43/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6409 - accuracy: 0.6469 - val_loss: 0.6440 - val_accuracy: 0.6410
# Epoch 44/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6486 - accuracy: 0.6313 - val_loss: 0.6411 - val_accuracy: 0.6381
# Epoch 45/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6324 - accuracy: 0.6400 - val_loss: 0.6403 - val_accuracy: 0.6366
# Epoch 46/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6487 - accuracy: 0.6338 - val_loss: 0.6351 - val_accuracy: 0.6555
# Epoch 47/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6361 - accuracy: 0.6431 - val_loss: 0.6359 - val_accuracy: 0.6541
# Epoch 48/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6423 - accuracy: 0.6594 - val_loss: 0.6410 - val_accuracy: 0.6439
# Epoch 49/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6363 - accuracy: 0.6463 - val_loss: 0.6432 - val_accuracy: 0.6395
# Epoch 50/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6362 - accuracy: 0.6550 - val_loss: 0.6433 - val_accuracy: 0.6366
# Epoch 51/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6400 - accuracy: 0.6538 - val_loss: 0.6428 - val_accuracy: 0.6410
# Epoch 52/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6336 - accuracy: 0.6456 - val_loss: 0.6386 - val_accuracy: 0.6453
# Epoch 53/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6453 - accuracy: 0.6363 - val_loss: 0.6352 - val_accuracy: 0.6497
# Epoch 54/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6345 - accuracy: 0.6456 - val_loss: 0.6354 - val_accuracy: 0.6512
# Epoch 55/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6376 - accuracy: 0.6513 - val_loss: 0.6370 - val_accuracy: 0.6439
# Epoch 56/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6354 - accuracy: 0.6481 - val_loss: 0.6346 - val_accuracy: 0.6468
# Epoch 57/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6340 - accuracy: 0.6612 - val_loss: 0.6344 - val_accuracy: 0.6483
# Epoch 58/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6351 - accuracy: 0.6456 - val_loss: 0.6367 - val_accuracy: 0.6453
# Epoch 59/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6323 - accuracy: 0.6494 - val_loss: 0.6369 - val_accuracy: 0.6366
# Epoch 60/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6348 - accuracy: 0.6413 - val_loss: 0.6323 - val_accuracy: 0.6468
# Epoch 61/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6379 - accuracy: 0.6425 - val_loss: 0.6382 - val_accuracy: 0.6453
# Epoch 62/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6296 - accuracy: 0.6687 - val_loss: 0.6376 - val_accuracy: 0.6395
# Epoch 63/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6303 - accuracy: 0.6575 - val_loss: 0.6379 - val_accuracy: 0.6381
# Epoch 64/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6312 - accuracy: 0.6600 - val_loss: 0.6398 - val_accuracy: 0.6381
# Epoch 65/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6269 - accuracy: 0.6544 - val_loss: 0.6401 - val_accuracy: 0.6381
# Epoch 66/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6293 - accuracy: 0.6581 - val_loss: 0.6359 - val_accuracy: 0.6395
# Epoch 67/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6226 - accuracy: 0.6612 - val_loss: 0.6375 - val_accuracy: 0.6424
# Epoch 68/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6428 - accuracy: 0.6475 - val_loss: 0.6349 - val_accuracy: 0.6395
# Epoch 69/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6391 - accuracy: 0.6413 - val_loss: 0.6374 - val_accuracy: 0.6381
# Epoch 70/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6351 - accuracy: 0.6456 - val_loss: 0.6370 - val_accuracy: 0.6395
# Epoch 71/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6334 - accuracy: 0.6600 - val_loss: 0.6332 - val_accuracy: 0.6468
# Epoch 72/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6262 - accuracy: 0.6550 - val_loss: 0.6345 - val_accuracy: 0.6410
# Epoch 73/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6357 - accuracy: 0.6525 - val_loss: 0.6388 - val_accuracy: 0.6337
# Epoch 74/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6397 - accuracy: 0.6481 - val_loss: 0.6344 - val_accuracy: 0.6395
# Epoch 75/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6254 - accuracy: 0.6569 - val_loss: 0.6338 - val_accuracy: 0.6395
# Epoch 76/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6219 - accuracy: 0.6594 - val_loss: 0.6346 - val_accuracy: 0.6395
# Epoch 77/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6320 - accuracy: 0.6538 - val_loss: 0.6337 - val_accuracy: 0.6424
# Epoch 78/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6296 - accuracy: 0.6612 - val_loss: 0.6370 - val_accuracy: 0.6439
# Epoch 79/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6336 - accuracy: 0.6488 - val_loss: 0.6367 - val_accuracy: 0.6453
# Epoch 80/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6360 - accuracy: 0.6494 - val_loss: 0.6358 - val_accuracy: 0.6395
# Epoch 81/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6396 - accuracy: 0.6481 - val_loss: 0.6336 - val_accuracy: 0.6395
# Epoch 82/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6414 - accuracy: 0.6338 - val_loss: 0.6319 - val_accuracy: 0.6424
# Epoch 83/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6290 - accuracy: 0.6494 - val_loss: 0.6331 - val_accuracy: 0.6381
# Epoch 84/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6248 - accuracy: 0.6631 - val_loss: 0.6312 - val_accuracy: 0.6468
# Epoch 85/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6332 - accuracy: 0.6500 - val_loss: 0.6290 - val_accuracy: 0.6468
# Epoch 86/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6181 - accuracy: 0.6712 - val_loss: 0.6311 - val_accuracy: 0.6483
# Epoch 87/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6331 - accuracy: 0.6500 - val_loss: 0.6337 - val_accuracy: 0.6439
# Epoch 88/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6275 - accuracy: 0.6550 - val_loss: 0.6336 - val_accuracy: 0.6453
# Epoch 89/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6278 - accuracy: 0.6575 - val_loss: 0.6334 - val_accuracy: 0.6453
# Epoch 90/300
# 16/16 [==============================] - 0s 12ms/step - loss: 0.6253 - accuracy: 0.6700 - val_loss: 0.6359 - val_accuracy: 0.6424
# Epoch 91/300
# 16/16 [==============================] - 0s 10ms/step - loss: 0.6280 - accuracy: 0.6650 - val_loss: 0.6373 - val_accuracy: 0.6439
# Epoch 92/300
# 16/16 [==============================] - 0s 10ms/step - loss: 0.6239 - accuracy: 0.6631 - val_loss: 0.6370 - val_accuracy: 0.6439
# Epoch 93/300
# 16/16 [==============================] - 0s 10ms/step - loss: 0.6382 - accuracy: 0.6513 - val_loss: 0.6382 - val_accuracy: 0.6453
# Epoch 94/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6279 - accuracy: 0.6631 - val_loss: 0.6384 - val_accuracy: 0.6410
# Epoch 95/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6144 - accuracy: 0.6637 - val_loss: 0.6353 - val_accuracy: 0.6453
# Epoch 96/300
# 16/16 [==============================] - 0s 8ms/step - loss: 0.6350 - accuracy: 0.6550 - val_loss: 0.6372 - val_accuracy: 0.6352
# Epoch 97/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6202 - accuracy: 0.6612 - val_loss: 0.6346 - val_accuracy: 0.6410
# Epoch 98/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6271 - accuracy: 0.6519 - val_loss: 0.6339 - val_accuracy: 0.6366
# Epoch 99/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6189 - accuracy: 0.6737 - val_loss: 0.6359 - val_accuracy: 0.6395
# Epoch 100/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6242 - accuracy: 0.6506 - val_loss: 0.6337 - val_accuracy: 0.6381
# Epoch 101/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6178 - accuracy: 0.6644 - val_loss: 0.6342 - val_accuracy: 0.6395
# Epoch 102/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6273 - accuracy: 0.6706 - val_loss: 0.6320 - val_accuracy: 0.6439
# Epoch 103/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6239 - accuracy: 0.6644 - val_loss: 0.6374 - val_accuracy: 0.6395
# Epoch 104/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6246 - accuracy: 0.6575 - val_loss: 0.6367 - val_accuracy: 0.6308
# Epoch 105/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6206 - accuracy: 0.6744 - val_loss: 0.6332 - val_accuracy: 0.6439
# Epoch 106/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6278 - accuracy: 0.6500 - val_loss: 0.6377 - val_accuracy: 0.6352
# Epoch 107/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6264 - accuracy: 0.6494 - val_loss: 0.6378 - val_accuracy: 0.6250
# Epoch 108/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6238 - accuracy: 0.6600 - val_loss: 0.6340 - val_accuracy: 0.6308
# Epoch 109/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6224 - accuracy: 0.6600 - val_loss: 0.6362 - val_accuracy: 0.6337
# Epoch 110/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6236 - accuracy: 0.6631 - val_loss: 0.6361 - val_accuracy: 0.6352
# Epoch 111/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6065 - accuracy: 0.6812 - val_loss: 0.6400 - val_accuracy: 0.6366
# Epoch 112/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6233 - accuracy: 0.6650 - val_loss: 0.6356 - val_accuracy: 0.6468
# Epoch 113/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6339 - accuracy: 0.6481 - val_loss: 0.6342 - val_accuracy: 0.6439
# Epoch 114/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6215 - accuracy: 0.6600 - val_loss: 0.6328 - val_accuracy: 0.6453
# Epoch 115/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6124 - accuracy: 0.6656 - val_loss: 0.6309 - val_accuracy: 0.6570
# Epoch 116/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6283 - accuracy: 0.6550 - val_loss: 0.6327 - val_accuracy: 0.6468
# Epoch 117/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6204 - accuracy: 0.6600 - val_loss: 0.6352 - val_accuracy: 0.6366
# Epoch 118/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6292 - accuracy: 0.6594 - val_loss: 0.6389 - val_accuracy: 0.6323
# Epoch 119/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6212 - accuracy: 0.6631 - val_loss: 0.6429 - val_accuracy: 0.6294
# Epoch 120/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6194 - accuracy: 0.6612 - val_loss: 0.6425 - val_accuracy: 0.6250
# Epoch 121/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6180 - accuracy: 0.6644 - val_loss: 0.6381 - val_accuracy: 0.6279
# Epoch 122/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6239 - accuracy: 0.6625 - val_loss: 0.6373 - val_accuracy: 0.6366
# Epoch 123/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6142 - accuracy: 0.6687 - val_loss: 0.6365 - val_accuracy: 0.6468
# Epoch 124/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6227 - accuracy: 0.6650 - val_loss: 0.6362 - val_accuracy: 0.6395
# Epoch 125/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6116 - accuracy: 0.6712 - val_loss: 0.6353 - val_accuracy: 0.6381
# Epoch 126/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6295 - accuracy: 0.6581 - val_loss: 0.6369 - val_accuracy: 0.6381
# Epoch 127/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6164 - accuracy: 0.6725 - val_loss: 0.6379 - val_accuracy: 0.6366
# Epoch 128/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6112 - accuracy: 0.6787 - val_loss: 0.6389 - val_accuracy: 0.6424
# Epoch 129/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6196 - accuracy: 0.6612 - val_loss: 0.6390 - val_accuracy: 0.6410
# Epoch 130/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6157 - accuracy: 0.6662 - val_loss: 0.6377 - val_accuracy: 0.6410
# Epoch 131/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6135 - accuracy: 0.6606 - val_loss: 0.6363 - val_accuracy: 0.6410
# Epoch 132/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6202 - accuracy: 0.6594 - val_loss: 0.6327 - val_accuracy: 0.6584
# Epoch 133/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6255 - accuracy: 0.6594 - val_loss: 0.6354 - val_accuracy: 0.6483
# Epoch 134/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6217 - accuracy: 0.6737 - val_loss: 0.6343 - val_accuracy: 0.6468
# Epoch 135/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6261 - accuracy: 0.6562 - val_loss: 0.6374 - val_accuracy: 0.6410
# Epoch 136/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6209 - accuracy: 0.6687 - val_loss: 0.6363 - val_accuracy: 0.6395
# Epoch 137/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6254 - accuracy: 0.6631 - val_loss: 0.6379 - val_accuracy: 0.6352
# Epoch 138/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6232 - accuracy: 0.6538 - val_loss: 0.6379 - val_accuracy: 0.6366
# Epoch 139/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6181 - accuracy: 0.6594 - val_loss: 0.6393 - val_accuracy: 0.6323
# Epoch 140/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6192 - accuracy: 0.6756 - val_loss: 0.6367 - val_accuracy: 0.6424
# Epoch 141/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6145 - accuracy: 0.6781 - val_loss: 0.6387 - val_accuracy: 0.6366
# Epoch 142/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6229 - accuracy: 0.6619 - val_loss: 0.6400 - val_accuracy: 0.6337
# Epoch 143/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6215 - accuracy: 0.6569 - val_loss: 0.6358 - val_accuracy: 0.6424
# Epoch 144/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6219 - accuracy: 0.6656 - val_loss: 0.6367 - val_accuracy: 0.6410
# Epoch 145/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6198 - accuracy: 0.6681 - val_loss: 0.6385 - val_accuracy: 0.6424
# Epoch 146/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6151 - accuracy: 0.6700 - val_loss: 0.6391 - val_accuracy: 0.6453
# Epoch 147/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6181 - accuracy: 0.6669 - val_loss: 0.6338 - val_accuracy: 0.6439
# Epoch 148/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6072 - accuracy: 0.6675 - val_loss: 0.6313 - val_accuracy: 0.6526
# Epoch 149/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6194 - accuracy: 0.6556 - val_loss: 0.6316 - val_accuracy: 0.6512
# Epoch 150/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6298 - accuracy: 0.6575 - val_loss: 0.6348 - val_accuracy: 0.6410
# Epoch 151/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6100 - accuracy: 0.6850 - val_loss: 0.6332 - val_accuracy: 0.6395
# Epoch 152/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6265 - accuracy: 0.6575 - val_loss: 0.6369 - val_accuracy: 0.6366
# Epoch 153/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6172 - accuracy: 0.6750 - val_loss: 0.6347 - val_accuracy: 0.6410
# Epoch 154/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6158 - accuracy: 0.6675 - val_loss: 0.6353 - val_accuracy: 0.6366
# Epoch 155/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6171 - accuracy: 0.6762 - val_loss: 0.6370 - val_accuracy: 0.6381
# Epoch 156/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6129 - accuracy: 0.6712 - val_loss: 0.6375 - val_accuracy: 0.6366
# Epoch 157/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6157 - accuracy: 0.6800 - val_loss: 0.6415 - val_accuracy: 0.6352
# Epoch 158/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6178 - accuracy: 0.6650 - val_loss: 0.6360 - val_accuracy: 0.6395
# Epoch 159/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6235 - accuracy: 0.6538 - val_loss: 0.6348 - val_accuracy: 0.6323
# Epoch 160/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6302 - accuracy: 0.6456 - val_loss: 0.6350 - val_accuracy: 0.6265
# Epoch 161/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6208 - accuracy: 0.6662 - val_loss: 0.6350 - val_accuracy: 0.6265
# Epoch 162/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6274 - accuracy: 0.6600 - val_loss: 0.6332 - val_accuracy: 0.6395
# Epoch 163/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6116 - accuracy: 0.6637 - val_loss: 0.6364 - val_accuracy: 0.6352
# Epoch 164/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6153 - accuracy: 0.6631 - val_loss: 0.6354 - val_accuracy: 0.6352
# Epoch 165/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6207 - accuracy: 0.6587 - val_loss: 0.6326 - val_accuracy: 0.6410
# Epoch 166/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6126 - accuracy: 0.6681 - val_loss: 0.6323 - val_accuracy: 0.6424
# Epoch 167/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6122 - accuracy: 0.6762 - val_loss: 0.6372 - val_accuracy: 0.6453
# Epoch 168/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6188 - accuracy: 0.6606 - val_loss: 0.6401 - val_accuracy: 0.6323
# Epoch 169/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6153 - accuracy: 0.6662 - val_loss: 0.6393 - val_accuracy: 0.6279
# Epoch 170/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6254 - accuracy: 0.6562 - val_loss: 0.6392 - val_accuracy: 0.6250
# Epoch 171/300
# 16/16 [==============================] - 0s 8ms/step - loss: 0.6086 - accuracy: 0.6756 - val_loss: 0.6380 - val_accuracy: 0.6337
# Epoch 172/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6228 - accuracy: 0.6656 - val_loss: 0.6373 - val_accuracy: 0.6352
# Epoch 173/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6068 - accuracy: 0.6800 - val_loss: 0.6352 - val_accuracy: 0.6381
# Epoch 174/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6238 - accuracy: 0.6550 - val_loss: 0.6361 - val_accuracy: 0.6366
# Epoch 175/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6129 - accuracy: 0.6625 - val_loss: 0.6330 - val_accuracy: 0.6366
# Epoch 176/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6109 - accuracy: 0.6650 - val_loss: 0.6320 - val_accuracy: 0.6366
# Epoch 177/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6127 - accuracy: 0.6712 - val_loss: 0.6356 - val_accuracy: 0.6352
# Epoch 178/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6132 - accuracy: 0.6744 - val_loss: 0.6309 - val_accuracy: 0.6381
# Epoch 179/300
# 16/16 [==============================] - 0s 14ms/step - loss: 0.6091 - accuracy: 0.6756 - val_loss: 0.6342 - val_accuracy: 0.6366
# Epoch 180/300
# 16/16 [==============================] - 0s 10ms/step - loss: 0.6043 - accuracy: 0.6737 - val_loss: 0.6332 - val_accuracy: 0.6453
# Epoch 181/300
# 16/16 [==============================] - 0s 11ms/step - loss: 0.6125 - accuracy: 0.6731 - val_loss: 0.6333 - val_accuracy: 0.6424
# Epoch 182/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6151 - accuracy: 0.6719 - val_loss: 0.6339 - val_accuracy: 0.6453
# Epoch 183/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6137 - accuracy: 0.6687 - val_loss: 0.6316 - val_accuracy: 0.6483
# Epoch 184/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6157 - accuracy: 0.6675 - val_loss: 0.6299 - val_accuracy: 0.6483
# Epoch 185/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6000 - accuracy: 0.6825 - val_loss: 0.6300 - val_accuracy: 0.6468
# Epoch 186/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6210 - accuracy: 0.6606 - val_loss: 0.6346 - val_accuracy: 0.6395
# Epoch 187/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6148 - accuracy: 0.6706 - val_loss: 0.6390 - val_accuracy: 0.6308
# Epoch 188/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6120 - accuracy: 0.6706 - val_loss: 0.6345 - val_accuracy: 0.6410
# Epoch 189/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6109 - accuracy: 0.6619 - val_loss: 0.6343 - val_accuracy: 0.6424
# Epoch 190/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6090 - accuracy: 0.6775 - val_loss: 0.6312 - val_accuracy: 0.6410
# Epoch 191/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6105 - accuracy: 0.6719 - val_loss: 0.6345 - val_accuracy: 0.6381
# Epoch 192/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6029 - accuracy: 0.6794 - val_loss: 0.6374 - val_accuracy: 0.6366
# Epoch 193/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6141 - accuracy: 0.6744 - val_loss: 0.6373 - val_accuracy: 0.6352
# Epoch 194/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6138 - accuracy: 0.6681 - val_loss: 0.6346 - val_accuracy: 0.6410
# Epoch 195/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6085 - accuracy: 0.6675 - val_loss: 0.6373 - val_accuracy: 0.6395
# Epoch 196/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6045 - accuracy: 0.6806 - val_loss: 0.6370 - val_accuracy: 0.6366
# Epoch 197/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6128 - accuracy: 0.6819 - val_loss: 0.6333 - val_accuracy: 0.6337
# Epoch 198/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6148 - accuracy: 0.6619 - val_loss: 0.6330 - val_accuracy: 0.6337
# Epoch 199/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6082 - accuracy: 0.6775 - val_loss: 0.6346 - val_accuracy: 0.6381
# Epoch 200/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.5940 - accuracy: 0.6888 - val_loss: 0.6387 - val_accuracy: 0.6381
# Epoch 201/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6039 - accuracy: 0.6806 - val_loss: 0.6341 - val_accuracy: 0.6366
# Epoch 202/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.5967 - accuracy: 0.6800 - val_loss: 0.6347 - val_accuracy: 0.6439
# Epoch 203/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6153 - accuracy: 0.6675 - val_loss: 0.6318 - val_accuracy: 0.6424
# Epoch 204/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6141 - accuracy: 0.6594 - val_loss: 0.6344 - val_accuracy: 0.6395
# Epoch 205/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6012 - accuracy: 0.6775 - val_loss: 0.6334 - val_accuracy: 0.6395
# Epoch 206/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6112 - accuracy: 0.6719 - val_loss: 0.6280 - val_accuracy: 0.6453
# Epoch 207/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6061 - accuracy: 0.6875 - val_loss: 0.6334 - val_accuracy: 0.6468
# Epoch 208/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6076 - accuracy: 0.6700 - val_loss: 0.6362 - val_accuracy: 0.6337
# Epoch 209/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6004 - accuracy: 0.6744 - val_loss: 0.6367 - val_accuracy: 0.6395
# Epoch 210/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6150 - accuracy: 0.6737 - val_loss: 0.6345 - val_accuracy: 0.6497
# Epoch 211/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6047 - accuracy: 0.6687 - val_loss: 0.6351 - val_accuracy: 0.6497
# Epoch 212/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.5934 - accuracy: 0.6981 - val_loss: 0.6394 - val_accuracy: 0.6352
# Epoch 213/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6033 - accuracy: 0.6737 - val_loss: 0.6408 - val_accuracy: 0.6308
# Epoch 214/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6090 - accuracy: 0.6756 - val_loss: 0.6391 - val_accuracy: 0.6308
# Epoch 215/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.5990 - accuracy: 0.6737 - val_loss: 0.6351 - val_accuracy: 0.6381
# Epoch 216/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6149 - accuracy: 0.6806 - val_loss: 0.6384 - val_accuracy: 0.6337
# Epoch 217/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6149 - accuracy: 0.6637 - val_loss: 0.6368 - val_accuracy: 0.6366
# Epoch 218/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6090 - accuracy: 0.6719 - val_loss: 0.6388 - val_accuracy: 0.6366
# Epoch 219/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6038 - accuracy: 0.6800 - val_loss: 0.6402 - val_accuracy: 0.6395
# Epoch 220/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6164 - accuracy: 0.6637 - val_loss: 0.6365 - val_accuracy: 0.6395
# Epoch 221/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.5965 - accuracy: 0.6900 - val_loss: 0.6366 - val_accuracy: 0.6453
# Epoch 222/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6009 - accuracy: 0.6837 - val_loss: 0.6429 - val_accuracy: 0.6381
# Epoch 223/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6118 - accuracy: 0.6781 - val_loss: 0.6384 - val_accuracy: 0.6410
# Epoch 224/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6005 - accuracy: 0.6806 - val_loss: 0.6384 - val_accuracy: 0.6410
# Epoch 225/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6105 - accuracy: 0.6700 - val_loss: 0.6363 - val_accuracy: 0.6468
# Epoch 226/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6046 - accuracy: 0.6737 - val_loss: 0.6357 - val_accuracy: 0.6439
# Epoch 227/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6111 - accuracy: 0.6650 - val_loss: 0.6382 - val_accuracy: 0.6337
# Epoch 228/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6123 - accuracy: 0.6775 - val_loss: 0.6423 - val_accuracy: 0.6279
# Epoch 229/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6181 - accuracy: 0.6506 - val_loss: 0.6374 - val_accuracy: 0.6468
# Epoch 230/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.5991 - accuracy: 0.6831 - val_loss: 0.6410 - val_accuracy: 0.6279
# Epoch 231/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6102 - accuracy: 0.6725 - val_loss: 0.6403 - val_accuracy: 0.6323
# Epoch 232/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6013 - accuracy: 0.6744 - val_loss: 0.6357 - val_accuracy: 0.6453
# Epoch 233/300
# 16/16 [==============================] - 0s 8ms/step - loss: 0.6040 - accuracy: 0.6712 - val_loss: 0.6360 - val_accuracy: 0.6366
# Epoch 234/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6207 - accuracy: 0.6538 - val_loss: 0.6376 - val_accuracy: 0.6352
# Epoch 235/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6010 - accuracy: 0.6744 - val_loss: 0.6382 - val_accuracy: 0.6410
# Epoch 236/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.5979 - accuracy: 0.6831 - val_loss: 0.6447 - val_accuracy: 0.6424
# Epoch 237/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6069 - accuracy: 0.6794 - val_loss: 0.6376 - val_accuracy: 0.6366
# Epoch 238/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6053 - accuracy: 0.6687 - val_loss: 0.6331 - val_accuracy: 0.6410
# Epoch 239/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.5984 - accuracy: 0.6825 - val_loss: 0.6373 - val_accuracy: 0.6483
# Epoch 240/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6035 - accuracy: 0.6819 - val_loss: 0.6359 - val_accuracy: 0.6497
# Epoch 241/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6097 - accuracy: 0.6706 - val_loss: 0.6371 - val_accuracy: 0.6483
# Epoch 242/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6053 - accuracy: 0.6781 - val_loss: 0.6431 - val_accuracy: 0.6337
# Epoch 243/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6020 - accuracy: 0.6831 - val_loss: 0.6474 - val_accuracy: 0.6279
# Epoch 244/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6101 - accuracy: 0.6762 - val_loss: 0.6415 - val_accuracy: 0.6381
# Epoch 245/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.5959 - accuracy: 0.6900 - val_loss: 0.6436 - val_accuracy: 0.6337
# Epoch 246/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6062 - accuracy: 0.6706 - val_loss: 0.6411 - val_accuracy: 0.6337
# Epoch 247/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.5876 - accuracy: 0.6894 - val_loss: 0.6422 - val_accuracy: 0.6424
# Epoch 248/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.5965 - accuracy: 0.6906 - val_loss: 0.6388 - val_accuracy: 0.6352
# Epoch 249/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.5991 - accuracy: 0.6856 - val_loss: 0.6409 - val_accuracy: 0.6439
# Epoch 250/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6032 - accuracy: 0.6694 - val_loss: 0.6391 - val_accuracy: 0.6453
# Epoch 251/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.5983 - accuracy: 0.6900 - val_loss: 0.6359 - val_accuracy: 0.6453
# Epoch 252/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6022 - accuracy: 0.6837 - val_loss: 0.6399 - val_accuracy: 0.6468
# Epoch 253/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6091 - accuracy: 0.6744 - val_loss: 0.6404 - val_accuracy: 0.6424
# Epoch 254/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6023 - accuracy: 0.6938 - val_loss: 0.6438 - val_accuracy: 0.6410
# Epoch 255/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6095 - accuracy: 0.6737 - val_loss: 0.6398 - val_accuracy: 0.6395
# Epoch 256/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.5991 - accuracy: 0.6794 - val_loss: 0.6352 - val_accuracy: 0.6483
# Epoch 257/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.5960 - accuracy: 0.6794 - val_loss: 0.6345 - val_accuracy: 0.6468
# Epoch 258/300
# 16/16 [==============================] - 0s 10ms/step - loss: 0.6104 - accuracy: 0.6681 - val_loss: 0.6360 - val_accuracy: 0.6570
# Epoch 259/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.5993 - accuracy: 0.6750 - val_loss: 0.6333 - val_accuracy: 0.6497
# Epoch 260/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.5884 - accuracy: 0.6869 - val_loss: 0.6332 - val_accuracy: 0.6424
# Epoch 261/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6117 - accuracy: 0.6775 - val_loss: 0.6393 - val_accuracy: 0.6439
# Epoch 262/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6055 - accuracy: 0.6694 - val_loss: 0.6391 - val_accuracy: 0.6541
# Epoch 263/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.5954 - accuracy: 0.6881 - val_loss: 0.6331 - val_accuracy: 0.6526
# Epoch 264/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.5974 - accuracy: 0.6744 - val_loss: 0.6323 - val_accuracy: 0.6541
# Epoch 265/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6215 - accuracy: 0.6769 - val_loss: 0.6321 - val_accuracy: 0.6439
# Epoch 266/300
# 16/16 [==============================] - 0s 10ms/step - loss: 0.5960 - accuracy: 0.6669 - val_loss: 0.6339 - val_accuracy: 0.6483
# Epoch 267/300
# 16/16 [==============================] - 0s 12ms/step - loss: 0.5875 - accuracy: 0.6831 - val_loss: 0.6364 - val_accuracy: 0.6468
# Epoch 268/300
# 16/16 [==============================] - 0s 10ms/step - loss: 0.5969 - accuracy: 0.6831 - val_loss: 0.6349 - val_accuracy: 0.6483
# Epoch 269/300
# 16/16 [==============================] - 0s 8ms/step - loss: 0.6072 - accuracy: 0.6712 - val_loss: 0.6308 - val_accuracy: 0.6483
# Epoch 270/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6135 - accuracy: 0.6687 - val_loss: 0.6325 - val_accuracy: 0.6410
# Epoch 271/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.5998 - accuracy: 0.6888 - val_loss: 0.6348 - val_accuracy: 0.6424
# Epoch 272/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.5947 - accuracy: 0.6944 - val_loss: 0.6355 - val_accuracy: 0.6323
# Epoch 273/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.5964 - accuracy: 0.6869 - val_loss: 0.6327 - val_accuracy: 0.6439
# Epoch 274/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6013 - accuracy: 0.6837 - val_loss: 0.6358 - val_accuracy: 0.6366
# Epoch 275/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6056 - accuracy: 0.6769 - val_loss: 0.6365 - val_accuracy: 0.6366
# Epoch 276/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.5931 - accuracy: 0.6800 - val_loss: 0.6344 - val_accuracy: 0.6468
# Epoch 277/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6010 - accuracy: 0.6769 - val_loss: 0.6342 - val_accuracy: 0.6395
# Epoch 278/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.5902 - accuracy: 0.6975 - val_loss: 0.6356 - val_accuracy: 0.6337
# Epoch 279/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.5936 - accuracy: 0.6925 - val_loss: 0.6374 - val_accuracy: 0.6352
# Epoch 280/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6007 - accuracy: 0.6819 - val_loss: 0.6334 - val_accuracy: 0.6294
# Epoch 281/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.5915 - accuracy: 0.6837 - val_loss: 0.6356 - val_accuracy: 0.6424
# Epoch 282/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.5931 - accuracy: 0.6781 - val_loss: 0.6298 - val_accuracy: 0.6439
# Epoch 283/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.5996 - accuracy: 0.6706 - val_loss: 0.6305 - val_accuracy: 0.6410
# Epoch 284/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.5852 - accuracy: 0.6913 - val_loss: 0.6381 - val_accuracy: 0.6395
# Epoch 285/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.5992 - accuracy: 0.6900 - val_loss: 0.6370 - val_accuracy: 0.6395
# Epoch 286/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.5945 - accuracy: 0.6988 - val_loss: 0.6342 - val_accuracy: 0.6424
# Epoch 287/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6085 - accuracy: 0.6806 - val_loss: 0.6322 - val_accuracy: 0.6541
# Epoch 288/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.5994 - accuracy: 0.6681 - val_loss: 0.6338 - val_accuracy: 0.6453
# Epoch 289/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6010 - accuracy: 0.6812 - val_loss: 0.6331 - val_accuracy: 0.6381
# Epoch 290/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.5854 - accuracy: 0.6900 - val_loss: 0.6389 - val_accuracy: 0.6381
# Epoch 291/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.5996 - accuracy: 0.6837 - val_loss: 0.6390 - val_accuracy: 0.6308
# Epoch 292/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.5855 - accuracy: 0.6969 - val_loss: 0.6381 - val_accuracy: 0.6323
# Epoch 293/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.5961 - accuracy: 0.6769 - val_loss: 0.6341 - val_accuracy: 0.6424
# Epoch 294/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6030 - accuracy: 0.6831 - val_loss: 0.6379 - val_accuracy: 0.6366
# Epoch 295/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.5848 - accuracy: 0.6963 - val_loss: 0.6412 - val_accuracy: 0.6366
# Epoch 296/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6056 - accuracy: 0.6781 - val_loss: 0.6404 - val_accuracy: 0.6279
# Epoch 297/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.5925 - accuracy: 0.6913 - val_loss: 0.6348 - val_accuracy: 0.6424
# Epoch 298/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.5933 - accuracy: 0.6862 - val_loss: 0.6354 - val_accuracy: 0.6439
# Epoch 299/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.5943 - accuracy: 0.6906 - val_loss: 0.6402 - val_accuracy: 0.6424
# Epoch 300/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6055 - accuracy: 0.6706 - val_loss: 0.6368 - val_accuracy: 0.6424

# %%
loss, acc = model.evaluate(test_dataset)
# Out:
# 10/10 [==============================] - 0s 3ms/step - loss: 0.6163 - accuracy: 0.6724

# %%
plt.figure(figsize=(7,6))
plt.plot(range(1, N_EPOCHS+1), hist.history['loss'], label='train loss')
plt.plot(range(1, N_EPOCHS+1), hist.history['val_loss'], label='validation loss')
plt.title("LOSS", fontsize=20)
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(7,6))
plt.plot(range(1, N_EPOCHS+1), hist.history['accuracy'], label='train accuracy')
plt.plot(range(1, N_EPOCHS+1), hist.history['val_accuracy'], label='validation accuracy')
plt.title("Accuracy", fontsize=20)
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.show()

# %%
new_data = X_test[:5]
pred = model.predict(new_data)
threshold = 0.5
result = (pred > threshold).astype(np.int8)
result
# Out:
# array([[0],
#        [0],
#        [0],
#        [0],
#        [0]], dtype=int8)

# %%
y_test[:5]
# Out:
# 2017    1
# 2533    0
# 589     0
# 482     0
# 2620    0
# Name: Potability, dtype: int64

# %%
pred=model.predict(X_test)
result=(pred>threshold).astype(np.int8)

# %%
plt.figure(figsize=(7,7))
ax = plt.gca()
cm = confusion_matrix(y_test, result)
disp = ConfusionMatrixDisplay(cm, # confusion matrix
                              display_labels=['0', '1']) # [음성레이블, 양성레이블]
disp.plot(cmap='Blues', ax=ax) # 출력
plt.title('Test set')
plt.show()

# %%
print("Accuracy:", accuracy_score(y_test, result)*100,'%') 
print("Recall:", recall_score(y_test, result)*100,'%') 
print('Precision:',precision_score(y_test, result)*100, '%') 
print('f1 score:',f1_score(y_test, result)*100, '%')
# Out:
# Accuracy: 67.24313326551373 %
# Recall: 26.80965147453083 %
# Precision: 67.11409395973155 %
# f1 score: 38.31417624521073 %
