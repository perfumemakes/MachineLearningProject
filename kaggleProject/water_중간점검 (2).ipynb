# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/water-potability/water_potability.csv

# %% [markdown]
# ### Feature Description
#
# ph: pH of 1. water (0 to 14).
#
# Hardness: Capacity of water to precipitate soap in mg/L.
#
# Solids: Total dissolved solids in ppm.
#
# Chloramines: Amount of Chloramines in ppm.
#
# Sulfate: Amount of Sulfates dissolved in mg/L.
#
# Conductivity: Electrical conductivity of water in μS/cm.
#
# Organic_carbon: Amount of organic carbon in ppm.
#
# Trihalomethanes: Amount of Trihalomethanes in μg/L.
#
# Turbidity: Measure of light emiting property of water in NTU.
#
# Potability: Indicates if water is safe for human consumption. Potable - 1 and Not potable - 0

# %%
data=pd.read_csv('/kaggle/input/water-potability/water_potability.csv')
data=pd.DataFrame(data)

# %%
data.head(10)
# Out:
#           ph    Hardness        Solids  Chloramines     Sulfate  Conductivity  \
# 0        NaN  204.890455  20791.318981     7.300212  368.516441    564.308654
# 1   3.716080  129.422921  18630.057858     6.635246         NaN    592.885359
# 2   8.099124  224.236259  19909.541732     9.275884         NaN    418.606213
# 3   8.316766  214.373394  22018.417441     8.059332  356.886136    363.266516
# 4   9.092223  181.101509  17978.986339     6.546600  310.135738    398.410813
# 5   5.584087  188.313324  28748.687739     7.544869  326.678363    280.467916
# 6  10.223862  248.071735  28749.716544     7.513408  393.663396    283.651634
# 7   8.635849  203.361523  13672.091764     4.563009  303.309771    474.607645
# 8        NaN  118.988579  14285.583854     7.804174  268.646941    389.375566
# 9  11.180284  227.231469  25484.508491     9.077200  404.041635    563.885481
#
#    Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       10.379783        86.990970   2.963135           0
# 1       15.180013        56.329076   4.500656           0
# 2       16.868637        66.420093   3.055934           0
# 3       18.436524       100.341674   4.628771           0
# 4       11.558279        31.997993   4.075075           0
# 5        8.399735        54.917862   2.559708           0
# 6       13.789695        84.603556   2.672989           0
# 7       12.363817        62.798309   4.401425           0
# 8       12.706049        53.928846   3.595017           0
# 9       17.927806        71.976601   4.370562           0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3276 entries, 0 to 3275
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ph               2785 non-null   float64
#  1   Hardness         3276 non-null   float64
#  2   Solids           3276 non-null   float64
#  3   Chloramines      3276 non-null   float64
#  4   Sulfate          2495 non-null   float64
#  5   Conductivity     3276 non-null   float64
#  6   Organic_carbon   3276 non-null   float64
#  7   Trihalomethanes  3114 non-null   float64
#  8   Turbidity        3276 non-null   float64
#  9   Potability       3276 non-null   int64
# dtypes: float64(9), int64(1)
# memory usage: 256.1 KB

# %%
sns.heatmap(data.isnull(), cbar=False)
plt.xticks(rotation=45)
plt.show()

# %%
data.isnull().sum()
# Out:
# ph                 491
# Hardness             0
# Solids               0
# Chloramines          0
# Sulfate            781
# Conductivity         0
# Organic_carbon       0
# Trihalomethanes    162
# Turbidity            0
# Potability           0
# dtype: int64

# %%
data['Potability'].value_counts()
# Out:
# 0    1998
# 1    1278
# Name: Potability, dtype: int64

# %% [markdown]
# # 결측치 처리(ph, Sulfate, Trihalomethanes)
#
# - 1. dropna(null값을 포함한 데이터는 drop한다) => 데이터가 1526개로 약 절반가량으로 줄어든다.=> RandomForest 정확도가 상대적으로 낮다
# - 2. null값이 있는 column을 drop한다.=> feature가 9개에서 6개로 줄어든다.=> RamdomForest 정확도가 상대적으로 낮다
# - 3. Feature의 평균값 또는 중앙값으로 대체한다.=> RandomForest 정확도가 상대적으로 높다.

# %%
# 결측치 평균값으로 대체-1

data.loc[(data['Potability'] == 0) & (data['ph'].isna()), 'ph'] = data[data['Potability'] == 0]['ph'].mean(skipna=True)
data.loc[(data['Potability'] == 1) & (data['ph'].isna()), 'ph'] = data[data['Potability'] == 1]['ph'].mean(skipna=True)


data.loc[(data['Potability'] == 0) & (data['Sulfate'].isna()), 'Sulfate'] = data[data['Potability'] == 0]['Sulfate'].mean(skipna=True)
data.loc[(data['Potability'] == 1) & (data['Sulfate'].isna()), 'Sulfate'] = data[data['Potability'] == 1]['Sulfate'].mean(skipna=True)


data.loc[(data['Potability'] == 0) & (data['Trihalomethanes'].isna()), 'Trihalomethanes'] = data[data['Potability'] == 0]['Trihalomethanes'].mean(skipna=True)
data.loc[(data['Potability'] == 1) & (data['Trihalomethanes'].isna()), 'Trihalomethanes'] = data[data['Potability'] == 1]['Trihalomethanes'].mean(skipna=True)

# %%
# 결측치 중앙값으로 대체-2

#data.loc[(data['Potability'] == 0) & (data['ph'].isna()), 'ph'] = data[data['Potability'] == 0]['ph'].median(skipna=True)
#data.loc[(data['Potability'] == 1) & (data['ph'].isna()), 'ph'] = data[data['Potability'] == 1]['ph'].median(skipna=True)


#data.loc[(data['Potability'] == 0) & (data['Sulfate'].isna()), 'Sulfate'] = data[data['Potability'] == 0]['Sulfate'].median(skipna=True)
#data.loc[(data['Potability'] == 1) & (data['Sulfate'].isna()), 'Sulfate'] = data[data['Potability'] == 1]['Sulfate'].median(skipna=True)


#data.loc[(data['Potability'] == 0) & (data['Trihalomethanes'].isna()), 'Trihalomethanes'] = data[data['Potability'] == 0]['Trihalomethanes'].median(skipna=True)
#data.loc[(data['Potability'] == 1) & (data['Trihalomethanes'].isna()), 'Trihalomethanes'] = data[data['Potability'] == 1]['Trihalomethanes'].median(skipna=True)

# %%
from sklearn.model_selection import train_test_split
X = data.iloc[:, :-1]
y = data.iloc[:, -1]
X_train,X_test,y_train,y_test=train_test_split(X, y, test_size=0.3, random_state=0)

# %%
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((2293, 9), (2293,), (983, 9), (983,))

# %% [markdown]
# ### Preprocessing

# %%
from sklearn.preprocessing import StandardScaler
sclaer=StandardScaler()
X_train=sclaer.fit_transform(X_train)
X_test=sclaer.transform(X_test)
X_train=pd.DataFrame(X_train)
X_test=pd.DataFrame(X_test)

# %%
X_train=X_train.rename(columns={0:'ph',1:'Hardness', 2:'Solids',3:'Chloramines',4:'Sulfate', 5:'Conductivity',6:'Organic_carbon',7:'Trihalomethanes', 8:'Turbidity'})
X_test=X_test.rename(columns={0:'ph',1:'Hardness', 2:'Solids',3:'Chloramines',4:'Sulfate', 5:'Conductivity',6:'Organic_carbon',7:'Trihalomethanes', 8:'Turbidity'})

# %% [markdown]
# ### SMOTE 적용해보기

# %%
from sklearn.datasets import make_classification
from sklearn.decomposition import PCA
from imblearn.over_sampling import SMOTE

# %%
#SMOTE?

# %%
#smote = SMOTE(sampling_strategy='auto',
#   random_state=None,
#    k_neighbors=5,
#    n_jobs=None,)
#X_resampled, y_resampled = smote.fit_resample(X_train,y_train)

# %%
#X_resampled.shape, y_resampled.shape

# %%
#y_resampled.value_counts()

# %%
#X_train=pd.concat([X_train, X_resampled])
#X_train.shape

# %%
#y_train=pd.concat([y_train,y_resampled])
#y_train.shape

# %%
#y_train=pd.DataFrame(y_train)
#y_test=pd.DataFrame(y_test)

# %% [markdown]
# ### Machine Learning
# - Modeling

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((2293, 9), (983, 9), (2293,), (983,))

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score


models_acc = []
models = [DecisionTreeClassifier(), LogisticRegression(), KNeighborsClassifier(), RandomForestClassifier(), GaussianNB(), SVC()]
for model in models:
    model.fit(X_train, y_train)    
    pred = model.predict(X_test)
    models_acc.append(accuracy_score(y_test, pred))

# %%
Model_list = pd.DataFrame({
    'Model Accuracy': models_acc, 
    "Model Name": ['DecisionTreeClassifier','LogisticRegression', 'KNeighborsClassifier', 'RandomForestClassifier', 'GaussianNB', 'SVC']
})
Model_list
# Out:
#    Model Accuracy              Model Name
# 0        0.740590  DecisionTreeClassifier
# 1        0.624619      LogisticRegression
# 2        0.635809    KNeighborsClassifier
# 3        0.809766  RandomForestClassifier
# 4        0.611394              GaussianNB
# 5        0.682604                     SVC

# %% [markdown]
# ### Gridsearch

# %%
from sklearn.model_selection import GridSearchCV

rfc = RandomForestClassifier(random_state=0)
#파라미터 후보 - 딕셔너리(key: 하이퍼 파라미터 이름, value: 후보리스트)
param_grid = {
    'n_estimators':[200],
    'max_depth':[6, 8, 10, 12],
    'min_samples_leaf':[2 ,4, 6, 8],
    'min_samples_split':[2 ,4, 6,8]
}

grid_search = GridSearchCV(rfc, #모델
                           param_grid=param_grid, #하이퍼 파라미터 후보
                           scoring='accuracy',# 평가 지표
                           cv=4, # cross validation의 fold 개수
                           n_jobs=-1) # 사용할 cpu의 개수: -1은 모든 cpu 전부 사용(병렬 학습)

# %%
grid_search.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=4, estimator=RandomForestClassifier(random_state=0), n_jobs=-1,
#              param_grid={'max_depth': [6, 8, 10, 12],
#                          'min_samples_leaf': [2, 4, 6, 8],
#                          'min_samples_split': [2, 4, 6, 8],
#                          'n_estimators': [200]},
#              scoring='accuracy')

# %%
df = pd.DataFrame(grid_search.cv_results_).sort_values('rank_test_score')#.filter(like='rank')
df
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 35       1.293935      0.021039         0.069301        0.000983
# 18       1.363071      0.125906         0.094820        0.029009
# 17       1.205606      0.011658         0.067796        0.001533
# 16       1.239524      0.017763         0.066195        0.002294
# 33       1.293917      0.003139         0.074199        0.004386
# ..            ...           ...              ...             ...
# 7        1.089741      0.010405         0.062788        0.001629
# 12       1.089708      0.031863         0.076505        0.019305
# 13       1.542375      0.465439         0.086578        0.032912
# 14       1.323517      0.236176         0.065551        0.000884
# 15       1.089294      0.004575         0.064619        0.001842
#
#    param_max_depth param_min_samples_leaf param_min_samples_split  \
# 35              10                      2                       8
# 18               8                      2                       6
# 17               8                      2                       4
# 16               8                      2                       2
# 33              10                      2                       4
# ..             ...                    ...                     ...
# 7                6                      4                       8
# 12               6                      8                       2
# 13               6                      8                       4
# 14               6                      8                       6
# 15               6                      8                       8
#
#    param_n_estimators                                             params  \
# 35                200  {'max_depth': 10, 'min_samples_leaf': 2, 'min_...
# 18                200  {'max_depth': 8, 'min_samples_leaf': 2, 'min_s...
# 17                200  {'max_depth': 8, 'min_samples_leaf': 2, 'min_s...
# 16                200  {'max_depth': 8, 'min_samples_leaf': 2, 'min_s...
# 33                200  {'max_depth': 10, 'min_samples_leaf': 2, 'min_...
# ..                ...                                                ...
# 7                 200  {'max_depth': 6, 'min_samples_leaf': 4, 'min_s...
# 12                200  {'max_depth': 6, 'min_samples_leaf': 8, 'min_s...
# 13                200  {'max_depth': 6, 'min_samples_leaf': 8, 'min_s...
# 14                200  {'max_depth': 6, 'min_samples_leaf': 8, 'min_s...
# 15                200  {'max_depth': 6, 'min_samples_leaf': 8, 'min_s...
#
#     split0_test_score  split1_test_score  split2_test_score  \
# 35           0.783972           0.787086           0.780105
# 18           0.789199           0.787086           0.780105
# 17           0.790941           0.788831           0.778360
# 16           0.790941           0.788831           0.778360
# 33           0.787456           0.790576           0.774869
# ..                ...                ...                ...
# 7            0.764808           0.781850           0.774869
# 12           0.770035           0.776614           0.774869
# 13           0.770035           0.776614           0.774869
# 14           0.770035           0.776614           0.774869
# 15           0.770035           0.776614           0.774869
#
#     split3_test_score  mean_test_score  std_test_score  rank_test_score
# 35           0.788831         0.784998        0.003318                1
# 18           0.783595         0.784996        0.003461                2
# 17           0.781850         0.784995        0.005099                3
# 16           0.781850         0.784995        0.005099                3
# 33           0.780105         0.783252        0.006154                5
# ..                ...              ...             ...              ...
# 7            0.762653         0.771045        0.007757               57
# 12           0.760908         0.770606        0.006096               61
# 13           0.760908         0.770606        0.006096               61
# 14           0.760908         0.770606        0.006096               61
# 15           0.760908         0.770606        0.006096               61
#
# [64 rows x 16 columns]

# %%
grid_search.best_score_
# Out:
# 0.7849982669609793

# %%
grid_search.best_params_
# Out:
# {'max_depth': 10,
#  'min_samples_leaf': 2,
#  'min_samples_split': 8,
#  'n_estimators': 200}

# %%
best_model = grid_search.best_estimator_
accuracy_score(y_test, best_model.predict(X_test))
# Out:
# 0.8128179043743642

# %%
pred=best_model.predict(X_test)

# %%
print("Accuracy:", accuracy_score(y_test, pred)*100,'%') 
print("Recall:", recall_score(y_test, pred)*100,'%') 
print('Precision:',precision_score(y_test, pred)*100, '%') 
print('f1 score:',f1_score(y_test, pred)*100, '%')
# Out:
# Accuracy: 81.28179043743641 %
# Recall: 59.78552278820375 %
# Precision: 86.7704280155642 %
# f1 score: 70.79365079365078 %

# %%
fi=best_model.feature_importances_
fi=pd.Series(fi, index=X_train.columns)
fi
# Out:
# ph                 0.221884
# Hardness           0.074465
# Solids             0.068808
# Chloramines        0.073824
# Sulfate            0.373828
# Conductivity       0.045820
# Organic_carbon     0.047374
# Trihalomethanes    0.051745
# Turbidity          0.042252
# dtype: float64

# %%
fi.sort_values().plot(kind='barh', figsize=(8,8))
plt.show()

# %% [markdown]
# ### Evaluation
# - RandomForest

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay
plt.figure(figsize=(7,7))
ax = plt.gca()
cm = confusion_matrix(y_test, pred)
disp = ConfusionMatrixDisplay(cm, # confusion matrix
                              display_labels=['0', '1']) # [음성레이블, 양성레이블]
disp.plot(cmap='Blues', ax=ax) # 출력
plt.title('Test set')
plt.show()

# %%
from sklearn.metrics import precision_score, average_precision_score,precision_recall_curve
from sklearn.metrics import PrecisionRecallDisplay 

rfc= best_model.predict_proba(X_test)[:, 1]
precision, recall, _ = precision_recall_curve(y_test, rfc)
ap_rfc = average_precision_score(y_test, rfc)

plt.figure(figsize=(8,8))
ax = plt.gca()
disp = PrecisionRecallDisplay(precision, recall, average_precision=ap_rfc)
disp.plot(ax=ax);
plt.grid(True)
plt.xticks(np.arange(0,1.1,0.1))
plt.yticks(np.arange(0,1.1,0.1))
plt.show()

# %%
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from sklearn.metrics import RocCurveDisplay

auc_rfc = roc_auc_score(y_test, rfc)
fprs_rfc, tprs_rfc, _ = roc_curve(y_test, rfc)


plt.figure(figsize=(7,6))
ax = plt.gca()
disp = RocCurveDisplay(fpr=fprs_rfc, tpr=tprs_rfc, roc_auc=auc_rfc, estimator_name='random forest')
disp.plot(ax=ax)
plt.show()

# %% [markdown]
# ### Deep Learning
# - MLP

# %%
import tensorflow as tf
from tensorflow import keras

model = keras.Sequential()
model.add(keras.layers.InputLayer((1,9))) 
model.add(keras.layers.Flatten())  
model.add(keras.layers.Dense(256, activation='relu'))
model.add(keras.layers.Dense(128, activation='relu'))
model.add(keras.layers.Dense(64, activation='relu'))
model.add(keras.layers.Dense(32, activation='relu'))
model.add(keras.layers.Dense(1, activation='softmax'))

# %%
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])
hist = model.fit(X_train, y_train, 
                  epochs=10,
                  batch_size=9,
                  validation_split=0.3 
                 )

test_loss, test_acc = model.evaluate(X_test, y_test)
# Out:
# Epoch 1/10
# 179/179 [==============================] - 2s 6ms/step - loss: 0.0000e+00 - accuracy: 0.3844 - val_loss: 0.0000e+00 - val_accuracy: 0.4186
# Epoch 2/10
# 179/179 [==============================] - 1s 5ms/step - loss: 0.0000e+00 - accuracy: 0.3844 - val_loss: 0.0000e+00 - val_accuracy: 0.4186
# Epoch 3/10
# 179/179 [==============================] - 1s 4ms/step - loss: 0.0000e+00 - accuracy: 0.3844 - val_loss: 0.0000e+00 - val_accuracy: 0.4186
# Epoch 4/10
# 179/179 [==============================] - 1s 5ms/step - loss: 0.0000e+00 - accuracy: 0.3844 - val_loss: 0.0000e+00 - val_accuracy: 0.4186
# Epoch 5/10
# 179/179 [==============================] - 1s 5ms/step - loss: 0.0000e+00 - accuracy: 0.3844 - val_loss: 0.0000e+00 - val_accuracy: 0.4186
# Epoch 6/10
# 179/179 [==============================] - 1s 4ms/step - loss: 0.0000e+00 - accuracy: 0.3844 - val_loss: 0.0000e+00 - val_accuracy: 0.4186
# Epoch 7/10
# 179/179 [==============================] - 1s 4ms/step - loss: 0.0000e+00 - accuracy: 0.3844 - val_loss: 0.0000e+00 - val_accuracy: 0.4186
# Epoch 8/10
# 179/179 [==============================] - 1s 5ms/step - loss: 0.0000e+00 - accuracy: 0.3844 - val_loss: 0.0000e+00 - val_accuracy: 0.4186
# Epoch 9/10
# 179/179 [==============================] - 1s 5ms/step - loss: 0.0000e+00 - accuracy: 0.3844 - val_loss: 0.0000e+00 - val_accuracy: 0.4186
# Epoch 10/10
# 179/179 [==============================] - 1s 4ms/step - loss: 0.0000e+00 - accuracy: 0.3844 - val_loss: 0.0000e+00 - val_accuracy: 0.4186
# 31/31 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.3795

# %%
model.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_7 (Flatten)          (None, 9)                 0
# _________________________________________________________________
# dense_39 (Dense)             (None, 256)               2560
# _________________________________________________________________
# dense_40 (Dense)             (None, 128)               32896
# _________________________________________________________________
# dense_41 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dense_42 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dense_43 (Dense)             (None, 1)                 33
# =================================================================
# Total params: 45,825
# Trainable params: 45,825
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.utils import plot_model
plot_model(model, to_file='model_shapes.png', show_shapes=True)

# %%
test_loss, test_acc = model.evaluate(X_test, y_test)
# Out:
# 31/31 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.3795

# %%
print(test_loss, test_acc)
# Out:
# 0.0 0.37945064902305603

# %% [markdown]
# ### Deep Learning
# - DNN

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

np.random.seed(0)
tf.random.set_seed(0)

# %%
X_train,X_val,y_train,y_val=train_test_split(X_train, y_train, test_size=0.3, random_state=0)

# %%
X_train.shape, X_val.shape, X_test.shape
# Out:
# ((1605, 9), (688, 9), (983, 9))

# %%
y_train.shape, y_val.shape, y_test.shape
# Out:
# ((1605,), (688,), (983,))

# %%
LEARNING_RATE = 0.001
N_EPOCHS = 200
N_BATCHS = 100

N_TRAIN = X_train.shape[0]
N_VAL = X_val.shape[0]
N_TEST = X_test.shape[0]

# %%
train_dataset = tf.data.Dataset.from_tensor_slices((X_train, y_train))\
                               .shuffle(N_TRAIN)\
                               .batch(N_BATCHS, drop_remainder=True)

val_dataset = tf.data.Dataset.from_tensor_slices((X_val, y_val)).batch(N_BATCHS)
test_dataset = tf.data.Dataset.from_tensor_slices((X_test, y_test)).batch(N_BATCHS)

# %%
def create_DNN_model():
    model = keras.Sequential()
    
    # 1. Flatten + Input Layer
    model.add(layers.Flatten(input_shape=(1,9))) 
    
    # 2. Hidden Layer
    model.add(layers.Dropout(0.3))
    model.add(layers.BatchNormalization())
    model.add(layers.Dense(units=256, activation='relu'))
    
    model.add(layers.Dropout(0.3))
    model.add(layers.BatchNormalization())
    model.add(layers.Dense(units=256, activation='relu'))
    
    model.add(layers.Dropout(0.3))
    model.add(layers.BatchNormalization())
    model.add(layers.Dense(units=128, activation='relu'))
    
    model.add(layers.Dropout(0.3))
    model.add(layers.BatchNormalization())
    model.add(layers.Dense(units=128, activation='relu'))
    
    model.add(layers.Dropout(0.3))
    model.add(layers.BatchNormalization())
    model.add(layers.Dense(units=64, activation='relu'))
    
    model.add(layers.Dropout(0.3))
    model.add(layers.BatchNormalization())
    model.add(layers.Dense(units=64, activation='relu'))
    
    # 3. Output Layer: 다중분류-unit수: class수, 각 unit이 클래스별 확률 => activation 함수: softmax
    model.add(layers.Dense(units=1, activation='sigmoid'))
    
    return model

# %%
model = create_DNN_model()

model.compile(optimizer=keras.optimizers.Adam(learning_rate=LEARNING_RATE), 
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_8 (Flatten)          (None, 9)                 0
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 9)                 0
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 9)                 36
# _________________________________________________________________
# dense_44 (Dense)             (None, 256)               2560
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 256)               0
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 256)               1024
# _________________________________________________________________
# dense_45 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 256)               0
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 256)               1024
# _________________________________________________________________
# dense_46 (Dense)             (None, 128)               32896
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 128)               0
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 128)               512
# _________________________________________________________________
# dense_47 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_16 (Dropout)         (None, 128)               0
# _________________________________________________________________
# batch_normalization_16 (Batc (None, 128)               512
# _________________________________________________________________
# dense_48 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dropout_17 (Dropout)         (None, 64)                0
# _________________________________________________________________
# batch_normalization_17 (Batc (None, 64)                256
# _________________________________________________________________
# dense_49 (Dense)             (None, 64)                4160
# _________________________________________________________________
# dense_50 (Dense)             (None, 1)                 65
# =================================================================
# Total params: 133,605
# Trainable params: 131,923
# Non-trainable params: 1,682
# _________________________________________________________________

# %%
hist = model.fit(train_dataset,
                 epochs=N_EPOCHS,
                 validation_data=val_dataset)
# Out:
# Epoch 1/200
# 16/16 [==============================] - 2s 25ms/step - loss: 0.7785 - accuracy: 0.4869 - val_loss: 0.6804 - val_accuracy: 0.5858
# Epoch 2/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.7129 - accuracy: 0.5544 - val_loss: 0.6780 - val_accuracy: 0.5858
# Epoch 3/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6965 - accuracy: 0.5825 - val_loss: 0.6819 - val_accuracy: 0.5858
# Epoch 4/200
# 16/16 [==============================] - 0s 13ms/step - loss: 0.6900 - accuracy: 0.5700 - val_loss: 0.6828 - val_accuracy: 0.5858
# Epoch 5/200
# 16/16 [==============================] - 0s 12ms/step - loss: 0.6834 - accuracy: 0.5931 - val_loss: 0.6826 - val_accuracy: 0.5858
# Epoch 6/200
# 16/16 [==============================] - 0s 12ms/step - loss: 0.6833 - accuracy: 0.5956 - val_loss: 0.6839 - val_accuracy: 0.5858
# Epoch 7/200
# 16/16 [==============================] - 0s 13ms/step - loss: 0.6694 - accuracy: 0.6056 - val_loss: 0.6857 - val_accuracy: 0.5858
# Epoch 8/200
# 16/16 [==============================] - 0s 9ms/step - loss: 0.6901 - accuracy: 0.5938 - val_loss: 0.6850 - val_accuracy: 0.5858
# Epoch 9/200
# 16/16 [==============================] - 0s 8ms/step - loss: 0.6632 - accuracy: 0.6106 - val_loss: 0.6910 - val_accuracy: 0.5858
# Epoch 10/200
# 16/16 [==============================] - 0s 8ms/step - loss: 0.6770 - accuracy: 0.5975 - val_loss: 0.6874 - val_accuracy: 0.5858
# Epoch 11/200
# 16/16 [==============================] - 0s 8ms/step - loss: 0.6880 - accuracy: 0.5906 - val_loss: 0.6902 - val_accuracy: 0.5872
# Epoch 12/200
# 16/16 [==============================] - 0s 8ms/step - loss: 0.6773 - accuracy: 0.6081 - val_loss: 0.6872 - val_accuracy: 0.5872
# Epoch 13/200
# 16/16 [==============================] - 0s 8ms/step - loss: 0.6493 - accuracy: 0.6313 - val_loss: 0.6917 - val_accuracy: 0.5872
# Epoch 14/200
# 16/16 [==============================] - 0s 8ms/step - loss: 0.6652 - accuracy: 0.6175 - val_loss: 0.6986 - val_accuracy: 0.5887
# Epoch 15/200
# 16/16 [==============================] - 0s 8ms/step - loss: 0.6647 - accuracy: 0.6075 - val_loss: 0.6999 - val_accuracy: 0.5916
# Epoch 16/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6672 - accuracy: 0.6056 - val_loss: 0.6874 - val_accuracy: 0.5930
# Epoch 17/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6565 - accuracy: 0.6269 - val_loss: 0.6839 - val_accuracy: 0.5959
# Epoch 18/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6533 - accuracy: 0.6313 - val_loss: 0.6825 - val_accuracy: 0.6003
# Epoch 19/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6609 - accuracy: 0.6162 - val_loss: 0.6833 - val_accuracy: 0.6003
# Epoch 20/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6532 - accuracy: 0.6256 - val_loss: 0.6778 - val_accuracy: 0.6003
# Epoch 21/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6621 - accuracy: 0.6275 - val_loss: 0.6705 - val_accuracy: 0.6061
# Epoch 22/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6629 - accuracy: 0.6231 - val_loss: 0.6657 - val_accuracy: 0.5974
# Epoch 23/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6629 - accuracy: 0.6275 - val_loss: 0.6655 - val_accuracy: 0.6076
# Epoch 24/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6401 - accuracy: 0.6450 - val_loss: 0.6605 - val_accuracy: 0.6148
# Epoch 25/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6402 - accuracy: 0.6456 - val_loss: 0.6542 - val_accuracy: 0.6221
# Epoch 26/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6625 - accuracy: 0.6150 - val_loss: 0.6533 - val_accuracy: 0.6177
# Epoch 27/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6650 - accuracy: 0.6194 - val_loss: 0.6531 - val_accuracy: 0.6206
# Epoch 28/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6453 - accuracy: 0.6313 - val_loss: 0.6521 - val_accuracy: 0.6235
# Epoch 29/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6475 - accuracy: 0.6381 - val_loss: 0.6523 - val_accuracy: 0.6221
# Epoch 30/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6518 - accuracy: 0.6438 - val_loss: 0.6501 - val_accuracy: 0.6279
# Epoch 31/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6449 - accuracy: 0.6413 - val_loss: 0.6495 - val_accuracy: 0.6279
# Epoch 32/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6545 - accuracy: 0.6369 - val_loss: 0.6506 - val_accuracy: 0.6265
# Epoch 33/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6469 - accuracy: 0.6319 - val_loss: 0.6502 - val_accuracy: 0.6192
# Epoch 34/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6566 - accuracy: 0.6294 - val_loss: 0.6549 - val_accuracy: 0.6235
# Epoch 35/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6416 - accuracy: 0.6269 - val_loss: 0.6519 - val_accuracy: 0.6221
# Epoch 36/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6448 - accuracy: 0.6481 - val_loss: 0.6522 - val_accuracy: 0.6192
# Epoch 37/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6423 - accuracy: 0.6431 - val_loss: 0.6501 - val_accuracy: 0.6221
# Epoch 38/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6423 - accuracy: 0.6550 - val_loss: 0.6513 - val_accuracy: 0.6221
# Epoch 39/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6497 - accuracy: 0.6381 - val_loss: 0.6478 - val_accuracy: 0.6250
# Epoch 40/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6390 - accuracy: 0.6350 - val_loss: 0.6430 - val_accuracy: 0.6294
# Epoch 41/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6493 - accuracy: 0.6444 - val_loss: 0.6411 - val_accuracy: 0.6294
# Epoch 42/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6432 - accuracy: 0.6513 - val_loss: 0.6409 - val_accuracy: 0.6279
# Epoch 43/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6450 - accuracy: 0.6413 - val_loss: 0.6418 - val_accuracy: 0.6279
# Epoch 44/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6527 - accuracy: 0.6363 - val_loss: 0.6398 - val_accuracy: 0.6323
# Epoch 45/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6352 - accuracy: 0.6419 - val_loss: 0.6403 - val_accuracy: 0.6308
# Epoch 46/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6457 - accuracy: 0.6325 - val_loss: 0.6359 - val_accuracy: 0.6381
# Epoch 47/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6373 - accuracy: 0.6519 - val_loss: 0.6364 - val_accuracy: 0.6395
# Epoch 48/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6404 - accuracy: 0.6506 - val_loss: 0.6399 - val_accuracy: 0.6424
# Epoch 49/200
# 16/16 [==============================] - 0s 8ms/step - loss: 0.6363 - accuracy: 0.6569 - val_loss: 0.6394 - val_accuracy: 0.6424
# Epoch 50/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6380 - accuracy: 0.6550 - val_loss: 0.6412 - val_accuracy: 0.6395
# Epoch 51/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6445 - accuracy: 0.6550 - val_loss: 0.6451 - val_accuracy: 0.6366
# Epoch 52/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6363 - accuracy: 0.6438 - val_loss: 0.6439 - val_accuracy: 0.6323
# Epoch 53/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6427 - accuracy: 0.6475 - val_loss: 0.6421 - val_accuracy: 0.6366
# Epoch 54/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6355 - accuracy: 0.6494 - val_loss: 0.6426 - val_accuracy: 0.6381
# Epoch 55/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6381 - accuracy: 0.6531 - val_loss: 0.6416 - val_accuracy: 0.6381
# Epoch 56/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6371 - accuracy: 0.6456 - val_loss: 0.6392 - val_accuracy: 0.6439
# Epoch 57/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6374 - accuracy: 0.6488 - val_loss: 0.6419 - val_accuracy: 0.6366
# Epoch 58/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6341 - accuracy: 0.6500 - val_loss: 0.6452 - val_accuracy: 0.6410
# Epoch 59/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6357 - accuracy: 0.6519 - val_loss: 0.6424 - val_accuracy: 0.6395
# Epoch 60/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6330 - accuracy: 0.6475 - val_loss: 0.6393 - val_accuracy: 0.6468
# Epoch 61/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6389 - accuracy: 0.6475 - val_loss: 0.6465 - val_accuracy: 0.6366
# Epoch 62/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6376 - accuracy: 0.6500 - val_loss: 0.6424 - val_accuracy: 0.6395
# Epoch 63/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6316 - accuracy: 0.6450 - val_loss: 0.6423 - val_accuracy: 0.6352
# Epoch 64/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6260 - accuracy: 0.6631 - val_loss: 0.6443 - val_accuracy: 0.6366
# Epoch 65/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6250 - accuracy: 0.6644 - val_loss: 0.6456 - val_accuracy: 0.6424
# Epoch 66/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6239 - accuracy: 0.6594 - val_loss: 0.6403 - val_accuracy: 0.6439
# Epoch 67/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6301 - accuracy: 0.6575 - val_loss: 0.6388 - val_accuracy: 0.6439
# Epoch 68/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6418 - accuracy: 0.6469 - val_loss: 0.6382 - val_accuracy: 0.6395
# Epoch 69/200
# 16/16 [==============================] - 0s 15ms/step - loss: 0.6301 - accuracy: 0.6519 - val_loss: 0.6442 - val_accuracy: 0.6352
# Epoch 70/200
# 16/16 [==============================] - 0s 11ms/step - loss: 0.6357 - accuracy: 0.6438 - val_loss: 0.6437 - val_accuracy: 0.6410
# Epoch 71/200
# 16/16 [==============================] - 0s 11ms/step - loss: 0.6378 - accuracy: 0.6550 - val_loss: 0.6390 - val_accuracy: 0.6453
# Epoch 72/200
# 16/16 [==============================] - 0s 9ms/step - loss: 0.6290 - accuracy: 0.6500 - val_loss: 0.6372 - val_accuracy: 0.6497
# Epoch 73/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6287 - accuracy: 0.6600 - val_loss: 0.6388 - val_accuracy: 0.6410
# Epoch 74/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6382 - accuracy: 0.6425 - val_loss: 0.6348 - val_accuracy: 0.6410
# Epoch 75/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6259 - accuracy: 0.6450 - val_loss: 0.6351 - val_accuracy: 0.6439
# Epoch 76/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6220 - accuracy: 0.6706 - val_loss: 0.6375 - val_accuracy: 0.6424
# Epoch 77/200
# 16/16 [==============================] - 0s 9ms/step - loss: 0.6246 - accuracy: 0.6612 - val_loss: 0.6367 - val_accuracy: 0.6424
# Epoch 78/200
# 16/16 [==============================] - 0s 10ms/step - loss: 0.6337 - accuracy: 0.6513 - val_loss: 0.6384 - val_accuracy: 0.6439
# Epoch 79/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6327 - accuracy: 0.6463 - val_loss: 0.6389 - val_accuracy: 0.6439
# Epoch 80/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6374 - accuracy: 0.6488 - val_loss: 0.6395 - val_accuracy: 0.6410
# Epoch 81/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6404 - accuracy: 0.6506 - val_loss: 0.6371 - val_accuracy: 0.6453
# Epoch 82/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6424 - accuracy: 0.6363 - val_loss: 0.6369 - val_accuracy: 0.6410
# Epoch 83/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6376 - accuracy: 0.6519 - val_loss: 0.6373 - val_accuracy: 0.6308
# Epoch 84/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6238 - accuracy: 0.6606 - val_loss: 0.6357 - val_accuracy: 0.6410
# Epoch 85/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6327 - accuracy: 0.6556 - val_loss: 0.6344 - val_accuracy: 0.6410
# Epoch 86/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6197 - accuracy: 0.6669 - val_loss: 0.6344 - val_accuracy: 0.6410
# Epoch 87/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6275 - accuracy: 0.6631 - val_loss: 0.6366 - val_accuracy: 0.6381
# Epoch 88/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6305 - accuracy: 0.6575 - val_loss: 0.6374 - val_accuracy: 0.6366
# Epoch 89/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6326 - accuracy: 0.6581 - val_loss: 0.6369 - val_accuracy: 0.6395
# Epoch 90/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6256 - accuracy: 0.6594 - val_loss: 0.6375 - val_accuracy: 0.6381
# Epoch 91/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6241 - accuracy: 0.6575 - val_loss: 0.6371 - val_accuracy: 0.6424
# Epoch 92/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6268 - accuracy: 0.6619 - val_loss: 0.6366 - val_accuracy: 0.6453
# Epoch 93/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6365 - accuracy: 0.6481 - val_loss: 0.6385 - val_accuracy: 0.6453
# Epoch 94/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6291 - accuracy: 0.6669 - val_loss: 0.6410 - val_accuracy: 0.6453
# Epoch 95/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6162 - accuracy: 0.6650 - val_loss: 0.6388 - val_accuracy: 0.6453
# Epoch 96/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6358 - accuracy: 0.6538 - val_loss: 0.6418 - val_accuracy: 0.6483
# Epoch 97/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6216 - accuracy: 0.6625 - val_loss: 0.6406 - val_accuracy: 0.6410
# Epoch 98/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6292 - accuracy: 0.6556 - val_loss: 0.6407 - val_accuracy: 0.6395
# Epoch 99/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6145 - accuracy: 0.6706 - val_loss: 0.6411 - val_accuracy: 0.6381
# Epoch 100/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6276 - accuracy: 0.6506 - val_loss: 0.6352 - val_accuracy: 0.6512
# Epoch 101/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6190 - accuracy: 0.6706 - val_loss: 0.6347 - val_accuracy: 0.6439
# Epoch 102/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6243 - accuracy: 0.6506 - val_loss: 0.6341 - val_accuracy: 0.6424
# Epoch 103/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6228 - accuracy: 0.6650 - val_loss: 0.6421 - val_accuracy: 0.6424
# Epoch 104/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6214 - accuracy: 0.6575 - val_loss: 0.6419 - val_accuracy: 0.6395
# Epoch 105/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6207 - accuracy: 0.6687 - val_loss: 0.6384 - val_accuracy: 0.6453
# Epoch 106/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6286 - accuracy: 0.6556 - val_loss: 0.6413 - val_accuracy: 0.6453
# Epoch 107/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6239 - accuracy: 0.6456 - val_loss: 0.6411 - val_accuracy: 0.6366
# Epoch 108/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6205 - accuracy: 0.6731 - val_loss: 0.6369 - val_accuracy: 0.6366
# Epoch 109/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6166 - accuracy: 0.6644 - val_loss: 0.6389 - val_accuracy: 0.6352
# Epoch 110/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6239 - accuracy: 0.6550 - val_loss: 0.6401 - val_accuracy: 0.6381
# Epoch 111/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6082 - accuracy: 0.6719 - val_loss: 0.6429 - val_accuracy: 0.6395
# Epoch 112/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6239 - accuracy: 0.6600 - val_loss: 0.6381 - val_accuracy: 0.6468
# Epoch 113/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6296 - accuracy: 0.6519 - val_loss: 0.6380 - val_accuracy: 0.6410
# Epoch 114/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6269 - accuracy: 0.6538 - val_loss: 0.6360 - val_accuracy: 0.6453
# Epoch 115/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6085 - accuracy: 0.6706 - val_loss: 0.6325 - val_accuracy: 0.6555
# Epoch 116/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6304 - accuracy: 0.6494 - val_loss: 0.6308 - val_accuracy: 0.6555
# Epoch 117/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6197 - accuracy: 0.6650 - val_loss: 0.6343 - val_accuracy: 0.6483
# Epoch 118/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6289 - accuracy: 0.6525 - val_loss: 0.6377 - val_accuracy: 0.6366
# Epoch 119/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6195 - accuracy: 0.6687 - val_loss: 0.6401 - val_accuracy: 0.6366
# Epoch 120/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6230 - accuracy: 0.6619 - val_loss: 0.6399 - val_accuracy: 0.6352
# Epoch 121/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6167 - accuracy: 0.6681 - val_loss: 0.6380 - val_accuracy: 0.6395
# Epoch 122/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6213 - accuracy: 0.6706 - val_loss: 0.6378 - val_accuracy: 0.6424
# Epoch 123/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6160 - accuracy: 0.6731 - val_loss: 0.6384 - val_accuracy: 0.6410
# Epoch 124/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6178 - accuracy: 0.6669 - val_loss: 0.6382 - val_accuracy: 0.6395
# Epoch 125/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6075 - accuracy: 0.6744 - val_loss: 0.6374 - val_accuracy: 0.6424
# Epoch 126/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6271 - accuracy: 0.6587 - val_loss: 0.6375 - val_accuracy: 0.6453
# Epoch 127/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6148 - accuracy: 0.6706 - val_loss: 0.6355 - val_accuracy: 0.6453
# Epoch 128/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6191 - accuracy: 0.6681 - val_loss: 0.6341 - val_accuracy: 0.6410
# Epoch 129/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6218 - accuracy: 0.6575 - val_loss: 0.6344 - val_accuracy: 0.6453
# Epoch 130/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6132 - accuracy: 0.6694 - val_loss: 0.6349 - val_accuracy: 0.6453
# Epoch 131/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6124 - accuracy: 0.6662 - val_loss: 0.6365 - val_accuracy: 0.6483
# Epoch 132/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6176 - accuracy: 0.6625 - val_loss: 0.6355 - val_accuracy: 0.6453
# Epoch 133/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6233 - accuracy: 0.6637 - val_loss: 0.6397 - val_accuracy: 0.6395
# Epoch 134/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6224 - accuracy: 0.6694 - val_loss: 0.6387 - val_accuracy: 0.6395
# Epoch 135/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6236 - accuracy: 0.6637 - val_loss: 0.6421 - val_accuracy: 0.6395
# Epoch 136/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6236 - accuracy: 0.6669 - val_loss: 0.6394 - val_accuracy: 0.6395
# Epoch 137/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6254 - accuracy: 0.6675 - val_loss: 0.6398 - val_accuracy: 0.6352
# Epoch 138/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6233 - accuracy: 0.6600 - val_loss: 0.6398 - val_accuracy: 0.6279
# Epoch 139/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6258 - accuracy: 0.6606 - val_loss: 0.6409 - val_accuracy: 0.6308
# Epoch 140/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6164 - accuracy: 0.6656 - val_loss: 0.6396 - val_accuracy: 0.6352
# Epoch 141/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6140 - accuracy: 0.6837 - val_loss: 0.6398 - val_accuracy: 0.6265
# Epoch 142/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6225 - accuracy: 0.6631 - val_loss: 0.6423 - val_accuracy: 0.6250
# Epoch 143/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6204 - accuracy: 0.6619 - val_loss: 0.6377 - val_accuracy: 0.6366
# Epoch 144/200
# 16/16 [==============================] - 0s 9ms/step - loss: 0.6241 - accuracy: 0.6612 - val_loss: 0.6367 - val_accuracy: 0.6366
# Epoch 145/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6172 - accuracy: 0.6656 - val_loss: 0.6355 - val_accuracy: 0.6424
# Epoch 146/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6138 - accuracy: 0.6700 - val_loss: 0.6358 - val_accuracy: 0.6453
# Epoch 147/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6182 - accuracy: 0.6600 - val_loss: 0.6327 - val_accuracy: 0.6424
# Epoch 148/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6075 - accuracy: 0.6719 - val_loss: 0.6297 - val_accuracy: 0.6483
# Epoch 149/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6178 - accuracy: 0.6656 - val_loss: 0.6300 - val_accuracy: 0.6453
# Epoch 150/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6275 - accuracy: 0.6519 - val_loss: 0.6330 - val_accuracy: 0.6439
# Epoch 151/200
# 16/16 [==============================] - 0s 15ms/step - loss: 0.6041 - accuracy: 0.6844 - val_loss: 0.6301 - val_accuracy: 0.6497
# Epoch 152/200
# 16/16 [==============================] - 0s 10ms/step - loss: 0.6288 - accuracy: 0.6556 - val_loss: 0.6325 - val_accuracy: 0.6366
# Epoch 153/200
# 16/16 [==============================] - 0s 11ms/step - loss: 0.6187 - accuracy: 0.6637 - val_loss: 0.6332 - val_accuracy: 0.6366
# Epoch 154/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6185 - accuracy: 0.6619 - val_loss: 0.6318 - val_accuracy: 0.6410
# Epoch 155/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6201 - accuracy: 0.6694 - val_loss: 0.6321 - val_accuracy: 0.6439
# Epoch 156/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6128 - accuracy: 0.6787 - val_loss: 0.6342 - val_accuracy: 0.6352
# Epoch 157/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6209 - accuracy: 0.6706 - val_loss: 0.6402 - val_accuracy: 0.6294
# Epoch 158/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6209 - accuracy: 0.6550 - val_loss: 0.6356 - val_accuracy: 0.6366
# Epoch 159/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6232 - accuracy: 0.6644 - val_loss: 0.6344 - val_accuracy: 0.6366
# Epoch 160/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6295 - accuracy: 0.6469 - val_loss: 0.6349 - val_accuracy: 0.6323
# Epoch 161/200
# 16/16 [==============================] - 0s 8ms/step - loss: 0.6163 - accuracy: 0.6650 - val_loss: 0.6357 - val_accuracy: 0.6294
# Epoch 162/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6257 - accuracy: 0.6600 - val_loss: 0.6344 - val_accuracy: 0.6453
# Epoch 163/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6107 - accuracy: 0.6650 - val_loss: 0.6361 - val_accuracy: 0.6381
# Epoch 164/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6165 - accuracy: 0.6556 - val_loss: 0.6351 - val_accuracy: 0.6483
# Epoch 165/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6200 - accuracy: 0.6700 - val_loss: 0.6333 - val_accuracy: 0.6512
# Epoch 166/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6091 - accuracy: 0.6762 - val_loss: 0.6317 - val_accuracy: 0.6439
# Epoch 167/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6043 - accuracy: 0.6800 - val_loss: 0.6359 - val_accuracy: 0.6410
# Epoch 168/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6177 - accuracy: 0.6669 - val_loss: 0.6384 - val_accuracy: 0.6352
# Epoch 169/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6197 - accuracy: 0.6612 - val_loss: 0.6378 - val_accuracy: 0.6323
# Epoch 170/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6198 - accuracy: 0.6675 - val_loss: 0.6384 - val_accuracy: 0.6337
# Epoch 171/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6123 - accuracy: 0.6769 - val_loss: 0.6367 - val_accuracy: 0.6323
# Epoch 172/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6188 - accuracy: 0.6625 - val_loss: 0.6362 - val_accuracy: 0.6337
# Epoch 173/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6032 - accuracy: 0.6794 - val_loss: 0.6349 - val_accuracy: 0.6366
# Epoch 174/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6202 - accuracy: 0.6650 - val_loss: 0.6349 - val_accuracy: 0.6352
# Epoch 175/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6150 - accuracy: 0.6525 - val_loss: 0.6305 - val_accuracy: 0.6439
# Epoch 176/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6112 - accuracy: 0.6662 - val_loss: 0.6301 - val_accuracy: 0.6468
# Epoch 177/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6148 - accuracy: 0.6706 - val_loss: 0.6333 - val_accuracy: 0.6483
# Epoch 178/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6156 - accuracy: 0.6687 - val_loss: 0.6291 - val_accuracy: 0.6497
# Epoch 179/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6125 - accuracy: 0.6662 - val_loss: 0.6328 - val_accuracy: 0.6453
# Epoch 180/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6051 - accuracy: 0.6637 - val_loss: 0.6303 - val_accuracy: 0.6468
# Epoch 181/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6093 - accuracy: 0.6712 - val_loss: 0.6306 - val_accuracy: 0.6497
# Epoch 182/200
# 16/16 [==============================] - 0s 8ms/step - loss: 0.6154 - accuracy: 0.6694 - val_loss: 0.6324 - val_accuracy: 0.6439
# Epoch 183/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6151 - accuracy: 0.6650 - val_loss: 0.6336 - val_accuracy: 0.6410
# Epoch 184/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6194 - accuracy: 0.6769 - val_loss: 0.6358 - val_accuracy: 0.6352
# Epoch 185/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6056 - accuracy: 0.6725 - val_loss: 0.6365 - val_accuracy: 0.6366
# Epoch 186/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6121 - accuracy: 0.6737 - val_loss: 0.6362 - val_accuracy: 0.6395
# Epoch 187/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6141 - accuracy: 0.6737 - val_loss: 0.6385 - val_accuracy: 0.6439
# Epoch 188/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6154 - accuracy: 0.6687 - val_loss: 0.6366 - val_accuracy: 0.6424
# Epoch 189/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6105 - accuracy: 0.6637 - val_loss: 0.6360 - val_accuracy: 0.6424
# Epoch 190/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6111 - accuracy: 0.6700 - val_loss: 0.6320 - val_accuracy: 0.6410
# Epoch 191/200
# 16/16 [==============================] - 0s 8ms/step - loss: 0.6173 - accuracy: 0.6750 - val_loss: 0.6340 - val_accuracy: 0.6410
# Epoch 192/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6047 - accuracy: 0.6725 - val_loss: 0.6340 - val_accuracy: 0.6453
# Epoch 193/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6172 - accuracy: 0.6694 - val_loss: 0.6349 - val_accuracy: 0.6424
# Epoch 194/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6145 - accuracy: 0.6719 - val_loss: 0.6344 - val_accuracy: 0.6424
# Epoch 195/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6075 - accuracy: 0.6737 - val_loss: 0.6357 - val_accuracy: 0.6424
# Epoch 196/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6081 - accuracy: 0.6769 - val_loss: 0.6366 - val_accuracy: 0.6395
# Epoch 197/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6076 - accuracy: 0.6719 - val_loss: 0.6369 - val_accuracy: 0.6366
# Epoch 198/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6119 - accuracy: 0.6681 - val_loss: 0.6377 - val_accuracy: 0.6366
# Epoch 199/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6083 - accuracy: 0.6775 - val_loss: 0.6375 - val_accuracy: 0.6453
# Epoch 200/200
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6013 - accuracy: 0.6781 - val_loss: 0.6380 - val_accuracy: 0.6395

# %%
loss, acc = model.evaluate(test_dataset)
# Out:
# 10/10 [==============================] - 0s 3ms/step - loss: 0.6183 - accuracy: 0.6745

# %%
plt.figure(figsize=(7,6))
plt.plot(range(1, N_EPOCHS+1), hist.history['loss'], label='train loss')
plt.plot(range(1, N_EPOCHS+1), hist.history['val_loss'], label='validation loss')
plt.title("LOSS", fontsize=20)
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(7,6))
plt.plot(range(1, N_EPOCHS+1), hist.history['accuracy'], label='train accuracy')
plt.plot(range(1, N_EPOCHS+1), hist.history['val_accuracy'], label='validation accuracy')
plt.title("Accuracy", fontsize=20)
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.show()

# %%
new_data = X_test[:5]
pred = model.predict(new_data)
threshold = 0.5
result = (pred > threshold).astype(np.int8)
result
# Out:
# array([[1],
#        [0],
#        [0],
#        [0],
#        [0]], dtype=int8)

# %%
y_test[:5]
# Out:
# 2017    1
# 2533    0
# 589     0
# 482     0
# 2620    0
# Name: Potability, dtype: int64

# %%
pred=model.predict(X_test)
result=(pred>threshold).astype(np.int8)

# %%
plt.figure(figsize=(7,7))
ax = plt.gca()
cm = confusion_matrix(y_test, result)
disp = ConfusionMatrixDisplay(cm, # confusion matrix
                              display_labels=['0', '1']) # [음성레이블, 양성레이블]
disp.plot(cmap='Blues', ax=ax) # 출력
plt.title('Test set')
plt.show()
